# %% [markdown]
# <a href="https://colab.research.google.com/github/minjeong-kim-git/HUFS-RL-2022/blob/main/Day%2009/simple_td3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir TD3

# %%
# !pip install box2d-py
# !pip install gym[Box_2D]
# Out:
# Collecting box2d-py
#   Downloading box2d_py-2.3.8-cp37-cp37m-manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 4.1 MB/s
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8
# Requirement already satisfied: gym[Box_2D] in /usr/local/lib/python3.7/dist-packages (0.17.3)
# WARNING: gym 0.17.3 does not provide the extra 'box_2d'
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.4.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.19.5)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym[Box_2D]) (0.16.0)

# %%
import numpy as np
import torch as T
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import os

class ReplayBuffer():
    def __init__(self, max_size, input_shape, n_actions):
        self.mem_size = max_size
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size, *input_shape))
        self.new_state_memory = np.zeros((self.mem_size, *input_shape))
        self.action_memory = np.zeros((self.mem_size, n_actions))
        self.reward_memory = np.zeros(self.mem_size)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)

    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.terminal_memory[index] = done
        self.reward_memory[index] = reward
        self.action_memory[index] = action

        self.mem_cntr += 1

    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)

        batch = np.random.choice(max_mem, batch_size)

        states = self.state_memory[batch]
        states_ = self.new_state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        dones = self.terminal_memory[batch]

        return states, actions, rewards, states_, dones


class CriticNetwork(nn.Module):
    def __init__(self, beta, input_dims, fc1_dims, fc2_dims, n_actions,
            name, chkpt_dir='TD3'):
        super(CriticNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.name = name
        self.checkpoint_dir = chkpt_dir
        self.checkpoint_file = os.path.join(self.checkpoint_dir, name+'_td3')

        self.fc1 = nn.Linear(self.input_dims[0] + n_actions, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        self.q1 = nn.Linear(self.fc2_dims, 1)

        self.optimizer = optim.Adam(self.parameters(), lr=beta)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')

        self.to(self.device)

    def forward(self, state, action):
        q1_action_value = self.fc1(T.cat([state, action], dim=1))
        q1_action_value = F.relu(q1_action_value)
        q1_action_value = self.fc2(q1_action_value)
        q1_action_value = F.relu(q1_action_value)

        q1 = self.q1(q1_action_value)

        return q1

    def save_checkpoint(self):
        print('... saving checkpoint ...')
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        print('... loading checkpoint ...')
        self.load_state_dict(T.load(self.checkpoint_file))

class ActorNetwork(nn.Module):
    def __init__(self, alpha, input_dims, fc1_dims, fc2_dims,
            n_actions, name, chkpt_dir='TD3'):
        super(ActorNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.name = name
        self.checkpoint_dir = chkpt_dir
        self.checkpoint_file = os.path.join(self.checkpoint_dir, name+'_td3')

        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        self.mu = nn.Linear(self.fc2_dims, self.n_actions)

        self.optimizer = optim.Adam(self.parameters(), lr=alpha)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')

        self.to(self.device)

    def forward(self, state):
        prob = self.fc1(state)
        prob = F.relu(prob)
        prob = self.fc2(prob)
        prob = F.relu(prob)

        mu = T.tanh(self.mu(prob))

        return mu

    def save_checkpoint(self):
        print('... saving checkpoint ...')
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        print('... loading checkpoint ...')
        self.load_state_dict(T.load(self.checkpoint_file))


class Agent():
    def __init__(self, alpha, beta, input_dims, tau, env,
            gamma=0.99, update_actor_interval=2, warmup=1000,
            n_actions=2, max_size=1000000, layer1_size=400,
            layer2_size=300, batch_size=100, noise=0.1):
        self.gamma = gamma
        self.tau = tau
        self.max_action = env.action_space.high
        self.min_action = env.action_space.low
        self.memory = ReplayBuffer(max_size, input_dims, n_actions)
        self.batch_size = batch_size
        self.learn_step_cntr = 0
        self.time_step = 0
        self.warmup = warmup
        self.n_actions = n_actions
        self.update_actor_iter = update_actor_interval

        self.actor = ActorNetwork(alpha, input_dims, layer1_size,
                        layer2_size, n_actions=n_actions, name='actor')

        self.critic_1 = CriticNetwork(beta, input_dims, layer1_size,
                        layer2_size, n_actions=n_actions, name='critic_1')
        self.critic_2 = CriticNetwork(beta, input_dims, layer1_size,
                        layer2_size, n_actions=n_actions, name='critic_2')

        self.target_actor = ActorNetwork(alpha, input_dims, layer1_size,
                    layer2_size, n_actions=n_actions, name='target_actor')
        self.target_critic_1 = CriticNetwork(beta, input_dims, layer1_size,
                layer2_size, n_actions=n_actions, name='target_critic_1')
        self.target_critic_2 = CriticNetwork(beta, input_dims, layer1_size,
                layer2_size, n_actions=n_actions, name='target_critic_2')

        self.noise = noise
        self.update_network_parameters(tau=1)

    def choose_action(self, observation):
        if self.time_step < self.warmup:
            mu = T.tensor(np.random.normal(scale=self.noise, 
                                            size=(self.n_actions,)))
        else:
            state = T.tensor(observation, dtype=T.float).to(self.actor.device)
            mu = self.actor.forward(state).to(self.actor.device)
        mu_prime = mu + T.tensor(np.random.normal(scale=self.noise),
                                    dtype=T.float).to(self.actor.device)

        mu_prime = T.clamp(mu_prime, self.min_action[0], self.max_action[0])
        self.time_step += 1

        return mu_prime.cpu().detach().numpy()

    def remember(self, state, action, reward, new_state, done):
        self.memory.store_transition(state, action, reward, new_state, done)

    def learn(self):
        if self.memory.mem_cntr < self.batch_size:
            return 
        state, action, reward, new_state, done = \
                self.memory.sample_buffer(self.batch_size)

        reward = T.tensor(reward, dtype=T.float).to(self.critic_1.device)
        done = T.tensor(done).to(self.critic_1.device)
        state_ = T.tensor(new_state, dtype=T.float).to(self.critic_1.device)
        state = T.tensor(state, dtype=T.float).to(self.critic_1.device)
        action = T.tensor(action, dtype=T.float).to(self.critic_1.device)
        
        target_actions = self.target_actor.forward(state_)
        target_actions = target_actions + \
                T.clamp(T.tensor(np.random.normal(scale=0.2)), -0.5, 0.5)
        target_actions = T.clamp(target_actions, self.min_action[0], 
                                self.max_action[0])
        
        q1_ = self.target_critic_1.forward(state_, target_actions)
        q2_ = self.target_critic_2.forward(state_, target_actions)

        q1 = self.critic_1.forward(state, action)
        q2 = self.critic_2.forward(state, action)

        q1_[done] = 0.0
        q2_[done] = 0.0

        q1_ = q1_.view(-1)
        q2_ = q2_.view(-1)

        critic_value_ = T.min(q1_, q2_)

        target = reward + self.gamma*critic_value_
        target = target.view(self.batch_size, 1)

        self.critic_1.optimizer.zero_grad()
        self.critic_2.optimizer.zero_grad()

        q1_loss = F.mse_loss(target, q1)
        q2_loss = F.mse_loss(target, q2)
        critic_loss = q1_loss + q2_loss
        critic_loss.backward()
        self.critic_1.optimizer.step()
        self.critic_2.optimizer.step()

        self.learn_step_cntr += 1

        if self.learn_step_cntr % self.update_actor_iter != 0:
            return

        self.actor.optimizer.zero_grad()
        actor_q1_loss = self.critic_1.forward(state, self.actor.forward(state))
        actor_loss = -T.mean(actor_q1_loss)
        actor_loss.backward()
        self.actor.optimizer.step()

        self.update_network_parameters()

    def update_network_parameters(self, tau=None):
        if tau is None:
            tau = self.tau

        actor_params = self.actor.named_parameters()
        critic_1_params = self.critic_1.named_parameters()
        critic_2_params = self.critic_2.named_parameters()
        target_actor_params = self.target_actor.named_parameters()
        target_critic_1_params = self.target_critic_1.named_parameters()
        target_critic_2_params = self.target_critic_2.named_parameters()

        critic_1 = dict(critic_1_params)
        critic_2 = dict(critic_2_params)
        actor = dict(actor_params)
        target_actor = dict(target_actor_params)
        target_critic_1 = dict(target_critic_1_params)
        target_critic_2 = dict(target_critic_2_params)

        for name in critic_1:
            critic_1[name] = tau*critic_1[name].clone() + \
                    (1-tau)*target_critic_1[name].clone()

        for name in critic_2:
            critic_2[name] = tau*critic_2[name].clone() + \
                    (1-tau)*target_critic_2[name].clone()

        for name in actor:
            actor[name] = tau*actor[name].clone() + \
                    (1-tau)*target_actor[name].clone()

        self.target_critic_1.load_state_dict(critic_1)
        self.target_critic_2.load_state_dict(critic_2)
        self.target_actor.load_state_dict(actor)

    def save_models(self):
        self.actor.save_checkpoint()
        self.target_actor.save_checkpoint()
        self.critic_1.save_checkpoint()
        self.critic_2.save_checkpoint()
        self.target_critic_1.save_checkpoint()
        self.target_critic_2.save_checkpoint()

    def load_models(self):
        self.actor.load_checkpoint()
        self.target_actor.load_checkpoint()
        self.critic_1.load_checkpoint()
        self.critic_2.load_checkpoint()
        self.target_critic_1.load_checkpoint()
        self.target_critic_2.load_checkpoint()

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_learning_curve(x, scores, figure_file):
    running_avg = np.zeros(len(scores))
    for i in range(len(running_avg)):
        running_avg[i] = np.mean(scores[max(0, i-100):(i+1)])
    plt.plot(x, running_avg)
    plt.title('Running average of previous 100 scores')
    plt.savefig(figure_file)

# %%
import gym
import numpy as np

env = gym.make('LunarLanderContinuous-v2')
agent = Agent(alpha=0.001, beta=0.001,
        input_dims=env.observation_space.shape, tau=0.005,
        env=env, batch_size=100, layer1_size=400, layer2_size=300,
        n_actions=env.action_space.shape[0])
n_games = 1000
filename = 'TD3/' + 'LunarLanderContinuous_' + str(n_games) + '_games.png'

best_score = env.reward_range[0]
score_history = []

#agent.load_models()

for i in range(n_games):
    observation = env.reset()
    done = False
    score = 0
    while not done:
        action = agent.choose_action(observation)
        observation_, reward, done, info = env.step(action)
        agent.remember(observation, action, reward, observation_, done)
        agent.learn()
        score += reward
        observation = observation_
    score_history.append(score)
    avg_score = np.mean(score_history[-100:])

    if avg_score > best_score:
        best_score = avg_score
        agent.save_models()

    print('episode ', i, 'score %.1f' % score,
            'average score %.1f' % avg_score)

x = [i+1 for i in range(n_games)]
plot_learning_curve(x, score_history, filename)
# Out:
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  0 score -52.1 average score -52.1
# episode  1 score -278.0 average score -165.1
# episode  2 score -105.0 average score -145.0
# episode  3 score -77.6 average score -128.2
# episode  4 score -55.4 average score -113.6
# episode  5 score -73.9 average score -107.0
# episode  6 score -60.6 average score -100.4
# episode  7 score -260.0 average score -120.3
# episode  8 score -216.3 average score -131.0
# episode  9 score -131.1 average score -131.0
# episode  10 score -148.4 average score -132.6
# episode  11 score -230.9 average score -140.8
# episode  12 score -350.8 average score -156.9
# episode  13 score -231.5 average score -162.3
# episode  14 score -167.3 average score -162.6
# episode  15 score -162.9 average score -162.6
# episode  16 score -163.7 average score -162.7
# episode  17 score -110.6 average score -159.8
# episode  18 score -136.4 average score -158.6
# episode  19 score -118.9 average score -156.6
# episode  20 score -50.5 average score -151.5
# episode  21 score -186.9 average score -153.1
# episode  22 score -161.2 average score -153.5
# episode  23 score -55.2 average score -149.4
# episode  24 score -39.6 average score -145.0
# episode  25 score -249.9 average score -149.0
# episode  26 score -89.5 average score -146.8
# episode  27 score -28.1 average score -142.6
# episode  28 score -153.5 average score -143.0
# episode  29 score -93.0 average score -141.3
# episode  30 score -6.1 average score -136.9
# episode  31 score -26.7 average score -133.5
# episode  32 score -56.5 average score -131.2
# episode  33 score -83.7 average score -129.8
# episode  34 score -3.1 average score -126.1
# episode  35 score -60.8 average score -124.3
# episode  36 score -72.9 average score -122.9
# episode  37 score -100.6 average score -122.3
# episode  38 score -128.3 average score -122.5
# episode  39 score -84.9 average score -121.6
# episode  40 score -147.4 average score -122.2
# episode  41 score -118.7 average score -122.1
# episode  42 score -31.1 average score -120.0
# episode  43 score -178.0 average score -121.3
# episode  44 score -78.4 average score -120.4
# episode  45 score -116.6 average score -120.3
# episode  46 score -159.3 average score -121.1
# episode  47 score -107.8 average score -120.8
# episode  48 score -155.9 average score -121.5
# episode  49 score -210.0 average score -123.3
# episode  50 score -199.3 average score -124.8
# episode  51 score -178.9 average score -125.8
# episode  52 score -143.1 average score -126.2
# episode  53 score -122.6 average score -126.1
# episode  54 score -161.8 average score -126.7
# episode  55 score -155.9 average score -127.3
# episode  56 score -130.4 average score -127.3
# episode  57 score -8.1 average score -125.3
# episode  58 score -20.0 average score -123.5
# episode  59 score -162.6 average score -124.1
# episode  60 score -111.8 average score -123.9
# episode  61 score -54.2 average score -122.8
# episode  62 score -58.3 average score -121.8
# episode  63 score -56.3 average score -120.8
# episode  64 score -82.8 average score -120.2
# episode  65 score -46.1 average score -119.1
# episode  66 score -198.6 average score -120.2
# episode  67 score -17.1 average score -118.7
# episode  68 score -102.0 average score -118.5
# episode  69 score -89.6 average score -118.1
# episode  70 score -86.5 average score -117.6
# episode  71 score -91.3 average score -117.3
# episode  72 score -92.6 average score -116.9
# episode  73 score -267.2 average score -119.0
# episode  74 score -77.1 average score -118.4
# episode  75 score -70.5 average score -117.8
# episode  76 score -110.1 average score -117.7
# episode  77 score -69.3 average score -117.0
# episode  78 score -111.6 average score -117.0
# episode  79 score -57.7 average score -116.2
# episode  80 score -101.7 average score -116.1
# episode  81 score -56.8 average score -115.3
# episode  82 score -79.9 average score -114.9
# episode  83 score -25.8 average score -113.8
# episode  84 score -57.8 average score -113.2
# episode  85 score -36.0 average score -112.3
# episode  86 score -34.6 average score -111.4
# episode  87 score -108.8 average score -111.4
# episode  88 score -26.5 average score -110.4
# episode  89 score -22.2 average score -109.4
# episode  90 score -60.6 average score -108.9
# episode  91 score -86.7 average score -108.7
# episode  92 score -26.3 average score -107.8
# episode  93 score -29.1 average score -106.9
# episode  94 score -81.7 average score -106.7
# episode  95 score -71.3 average score -106.3
# episode  96 score -75.7 average score -106.0
# episode  97 score -261.0 average score -107.6
# episode  98 score -212.2 average score -108.6
# episode  99 score -108.3 average score -108.6
# episode  100 score -217.3 average score -110.3
# episode  101 score -59.5 average score -108.1
# episode  102 score -207.7 average score -109.1
# episode  103 score -94.7 average score -109.3
# episode  104 score -74.5 average score -109.5
# episode  105 score -77.9 average score -109.5
# episode  106 score -57.5 average score -109.5
# episode  107 score -84.1 average score -107.7
# episode  108 score -106.8 average score -106.6
# episode  109 score -82.6 average score -106.1
# episode  110 score -206.4 average score -106.7
# episode  111 score -43.2 average score -104.8
# episode  112 score -149.9 average score -102.8
# episode  113 score -104.7 average score -101.6
# episode  114 score -238.2 average score -102.3
# episode  115 score -93.4 average score -101.6
# episode  116 score -91.2 average score -100.9
# episode  117 score -287.2 average score -102.6
# episode  118 score -245.6 average score -103.7
# episode  119 score -10.9 average score -102.6
# episode  120 score -49.6 average score -102.6
# episode  121 score -107.8 average score -101.8
# episode  122 score -74.8 average score -101.0
# episode  123 score 178.0 average score -98.6
# episode  124 score -76.7 average score -99.0
# episode  125 score 189.2 average score -94.6
# episode  126 score -121.1 average score -94.9
# episode  127 score -79.3 average score -95.5
# episode  128 score -107.9 average score -95.0
# episode  129 score -61.3 average score -94.7
# episode  130 score 43.5 average score -94.2
# episode  131 score -57.2 average score -94.5
# episode  132 score -72.4 average score -94.6
# episode  133 score -0.3 average score -93.8
# episode  134 score 143.6 average score -92.3
# episode  135 score -102.4 average score -92.8
# episode  136 score 8.1 average score -92.0
# episode  137 score -54.6 average score -91.5
# episode  138 score -58.4 average score -90.8
# episode  139 score -7.2 average score -90.0
# episode  140 score -54.0 average score -89.1
# episode  141 score -20.1 average score -88.1
# episode  142 score -50.8 average score -88.3
# episode  143 score -57.2 average score -87.1
# episode  144 score -108.6 average score -87.4
# episode  145 score -88.5 average score -87.1
# episode  146 score -32.4 average score -85.8
# episode  147 score -44.9 average score -85.2
# episode  148 score -299.7 average score -86.6
# episode  149 score -141.8 average score -86.0
# episode  150 score -354.6 average score -87.5
# episode  151 score -50.3 average score -86.2
# episode  152 score 3.5 average score -84.8
# episode  153 score -55.2 average score -84.1
# episode  154 score -53.1 average score -83.0
# episode  155 score -22.8 average score -81.7
# episode  156 score -31.6 average score -80.7
# episode  157 score -25.1 average score -80.9
# episode  158 score -256.9 average score -83.2
# episode  159 score -17.3 average score -81.8
# episode  160 score -55.8 average score -81.2
# episode  161 score 21.5 average score -80.5
# episode  162 score -255.2 average score -82.4
# episode  163 score -296.7 average score -84.8
# episode  164 score 65.2 average score -83.3
# episode  165 score -255.9 average score -85.4
# episode  166 score -145.9 average score -84.9
# episode  167 score -138.6 average score -86.1
# episode  168 score -142.7 average score -86.5
# episode  169 score -41.8 average score -86.1
# episode  170 score -31.7 average score -85.5
# episode  171 score -80.1 average score -85.4
# episode  172 score 24.5 average score -84.2
# episode  173 score -141.6 average score -83.0
# episode  174 score -129.3 average score -83.5
# episode  175 score -15.3 average score -82.9
# episode  176 score -65.0 average score -82.5
# episode  177 score -260.7 average score -84.4
# episode  178 score -90.9 average score -84.2
# episode  179 score 223.4 average score -81.4
# episode  180 score 37.5 average score -80.0
# episode  181 score -16.5 average score -79.6
# episode  182 score -53.8 average score -79.3
# episode  183 score -97.0 average score -80.0
# episode  184 score -67.8 average score -80.1
# episode  185 score -99.1 average score -80.8
# episode  186 score 3.2 average score -80.4
# episode  187 score -101.1 average score -80.3
# episode  188 score -20.7 average score -80.3
# episode  189 score 200.5 average score -78.0
# episode  190 score 271.6 average score -74.7
# episode  191 score 164.5 average score -72.2
# episode  192 score -37.4 average score -72.3
# episode  193 score 158.6 average score -70.4
# episode  194 score -99.9 average score -70.6
# episode  195 score 192.5 average score -68.0
# episode  196 score 199.8 average score -65.2
# episode  197 score 234.2 average score -60.3
# episode  198 score -54.3 average score -58.7
# episode  199 score 230.3 average score -55.3
# episode  200 score 2.7 average score -53.1
# episode  201 score -9.2 average score -52.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  202 score 5.3 average score -50.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  203 score 11.7 average score -49.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  204 score -2.5 average score -48.7
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  205 score 247.4 average score -45.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  206 score 263.7 average score -42.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  207 score 273.4 average score -38.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  208 score 172.0 average score -35.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  209 score 44.0 average score -34.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  210 score 3.3 average score -32.5
# episode  211 score -52.7 average score -32.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  212 score 149.7 average score -29.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  213 score -59.4 average score -29.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  214 score 32.5 average score -26.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  215 score 18.7 average score -25.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  216 score -4.7 average score -24.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  217 score -149.1 average score -23.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  218 score -1.8 average score -20.6
# episode  219 score -110.1 average score -21.6
# episode  220 score 21.6 average score -20.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  221 score 14.9 average score -19.7
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  222 score -7.8 average score -19.0
# episode  223 score -110.8 average score -21.9
# episode  224 score -278.9 average score -23.9
# episode  225 score 237.5 average score -23.4
# episode  226 score -117.5 average score -23.4
# episode  227 score 261.4 average score -20.0
# episode  228 score -35.2 average score -19.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  229 score 185.1 average score -16.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  230 score 285.6 average score -14.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  231 score 279.2 average score -11.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  232 score 247.8 average score -7.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  233 score 171.6 average score -6.1
# episode  234 score -123.9 average score -8.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  235 score 241.9 average score -5.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  236 score 278.2 average score -2.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  237 score 23.8 average score -1.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  238 score 270.6 average score 1.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  239 score 252.6 average score 4.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  240 score 163.3 average score 6.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  241 score 254.4 average score 9.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  242 score 13.8 average score 9.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  243 score 207.6 average score 12.3
# episode  244 score -212.0 average score 11.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  245 score 76.6 average score 12.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  246 score 208.5 average score 15.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  247 score 219.6 average score 17.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  248 score 194.4 average score 22.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  249 score -23.5 average score 24.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  250 score 198.6 average score 29.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  251 score 111.0 average score 31.2
# episode  252 score -277.4 average score 28.4
# episode  253 score 38.0 average score 29.3
# episode  254 score -159.7 average score 28.2
# episode  255 score 86.1 average score 29.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  256 score 200.2 average score 31.7
# episode  257 score -239.9 average score 29.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  258 score 19.3 average score 32.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  259 score 152.3 average score 34.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  260 score 225.6 average score 36.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  261 score 156.0 average score 38.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  262 score 45.4 average score 41.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  263 score 156.0 average score 45.7
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  264 score 271.6 average score 47.7
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  265 score 227.4 average score 52.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  266 score 120.0 average score 55.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  267 score -124.8 average score 55.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  268 score 261.7 average score 59.4
# episode  269 score -83.0 average score 59.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  270 score 261.7 average score 61.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  271 score 190.9 average score 64.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  272 score 264.7 average score 67.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  273 score 259.5 average score 71.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  274 score 281.4 average score 75.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  275 score 231.8 average score 77.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  276 score 266.4 average score 80.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  277 score 239.9 average score 85.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  278 score 0.5 average score 86.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  279 score 245.9 average score 87.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  280 score 235.6 average score 89.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  281 score 288.4 average score 92.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  282 score 259.1 average score 95.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  283 score 142.1 average score 97.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  284 score 282.6 average score 101.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  285 score 188.7 average score 104.0
# episode  286 score -101.0 average score 103.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  287 score 225.8 average score 106.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  288 score 264.6 average score 109.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  289 score 271.8 average score 109.8
# episode  290 score 242.7 average score 109.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  291 score 232.6 average score 110.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  292 score 293.8 average score 113.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  293 score 256.0 average score 114.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  294 score 290.8 average score 118.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  295 score 222.0 average score 118.7
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  296 score 268.5 average score 119.4
# episode  297 score 210.6 average score 119.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  298 score 250.1 average score 122.2
# episode  299 score -38.2 average score 119.5
# episode  300 score 125.9 average score 120.7
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  301 score 250.9 average score 123.3
# episode  302 score -37.7 average score 122.9
# episode  303 score -28.1 average score 122.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  304 score 257.1 average score 125.1
# episode  305 score -23.6 average score 122.4
# episode  306 score 278.4 average score 122.5
# episode  307 score 109.7 average score 120.9
# episode  308 score 281.3 average score 122.0
# episode  309 score 199.4 average score 123.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  310 score 283.0 average score 126.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  311 score 263.8 average score 129.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  312 score 220.1 average score 130.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  313 score 242.5 average score 133.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  314 score 250.2 average score 135.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  315 score 257.1 average score 137.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  316 score 297.7 average score 140.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  317 score 268.6 average score 145.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  318 score 241.5 average score 147.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  319 score 263.0 average score 151.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  320 score 146.5 average score 152.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  321 score 240.4 average score 154.7
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  322 score 246.6 average score 157.2
# episode  323 score -128.8 average score 157.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  324 score 99.8 average score 160.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  325 score 246.6 average score 160.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  326 score 256.6 average score 164.6
# episode  327 score -171.6 average score 160.3
# episode  328 score 229.7 average score 163.0
# episode  329 score 254.5 average score 163.6
# episode  330 score -31.2 average score 160.5
# episode  331 score -6.7 average score 157.6
# episode  332 score 221.8 average score 157.4
# episode  333 score 235.9 average score 158.0
# episode  334 score -166.8 average score 157.6
# episode  335 score 270.4 average score 157.9
# episode  336 score 207.7 average score 157.2
# episode  337 score 232.6 average score 159.2
# episode  338 score 258.9 average score 159.1
# episode  339 score 235.2 average score 159.0
# episode  340 score 236.5 average score 159.7
# episode  341 score 286.3 average score 160.0
# episode  342 score 267.3 average score 162.5
# episode  343 score 267.4 average score 163.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  344 score 261.0 average score 167.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  345 score 271.1 average score 169.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  346 score 252.7 average score 170.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  347 score 295.4 average score 171.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  348 score 195.7 average score 171.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  349 score 268.7 average score 173.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  350 score 257.9 average score 174.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  351 score 190.5 average score 175.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  352 score 294.3 average score 181.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  353 score 285.5 average score 183.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  354 score 206.2 average score 187.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  355 score 202.9 average score 188.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  356 score 305.8 average score 189.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  357 score 247.8 average score 194.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  358 score 267.1 average score 196.8
# episode  359 score 36.4 average score 195.6
# episode  360 score 257.4 average score 195.9
# episode  361 score 222.7 average score 196.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  362 score 231.0 average score 198.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  363 score 229.3 average score 199.2
# episode  364 score 257.8 average score 199.0
# episode  365 score 3.9 average score 196.8
# episode  366 score 6.2 average score 195.7
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  367 score 286.6 average score 199.8
# episode  368 score 12.8 average score 197.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  369 score 233.9 average score 200.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  370 score 266.9 average score 200.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  371 score 251.4 average score 201.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  372 score 286.5 average score 201.3
# episode  373 score 239.9 average score 201.1
# episode  374 score 291.8 average score 201.2
# episode  375 score 232.2 average score 201.2
# episode  376 score 242.8 average score 201.0
# episode  377 score 258.4 average score 201.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  378 score 219.2 average score 203.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  379 score 295.8 average score 203.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  380 score 289.6 average score 204.4
# episode  381 score 269.4 average score 204.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  382 score 320.9 average score 204.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  383 score 264.4 average score 206.1
# episode  384 score 276.7 average score 206.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  385 score 246.8 average score 206.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  386 score 292.8 average score 210.5
# episode  387 score 16.3 average score 208.4
# episode  388 score 272.1 average score 208.5
# episode  389 score 226.9 average score 208.1
# episode  390 score 293.7 average score 208.6
# episode  391 score 217.0 average score 208.4
# episode  392 score 254.6 average score 208.0
# episode  393 score 261.8 average score 208.1
# episode  394 score 254.0 average score 207.7
# episode  395 score 259.3 average score 208.1
# episode  396 score 202.7 average score 207.4
# episode  397 score 276.0 average score 208.1
# episode  398 score 277.3 average score 208.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  399 score 263.0 average score 211.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  400 score 256.3 average score 212.7
# episode  401 score 248.2 average score 212.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  402 score 255.9 average score 215.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  403 score 281.5 average score 218.7
# episode  404 score 240.7 average score 218.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  405 score 250.2 average score 221.3
# episode  406 score 253.5 average score 221.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  407 score 284.6 average score 222.8
# episode  408 score 257.6 average score 222.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  409 score 252.8 average score 223.1
# episode  410 score 231.2 average score 222.5
# episode  411 score 260.0 average score 222.5
# episode  412 score 254.7 average score 222.8
# episode  413 score 236.7 average score 222.8
# episode  414 score 239.2 average score 222.7
# episode  415 score 266.9 average score 222.8
# episode  416 score 274.1 average score 222.5
# episode  417 score -33.7 average score 219.5
# episode  418 score 216.6 average score 219.3
# episode  419 score 294.3 average score 219.6
# episode  420 score 267.7 average score 220.8
# episode  421 score 262.1 average score 221.0
# episode  422 score -29.4 average score 218.2
# episode  423 score 316.1 average score 222.7
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  424 score 247.0 average score 224.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  425 score 249.8 average score 224.2
# episode  426 score 239.4 average score 224.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  427 score 250.5 average score 228.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  428 score 232.5 average score 228.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  429 score 266.1 average score 228.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  430 score 267.9 average score 231.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  431 score 245.1 average score 233.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  432 score 259.2 average score 234.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  433 score 249.6 average score 234.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  434 score 279.9 average score 238.9
# episode  435 score 266.2 average score 238.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  436 score 268.0 average score 239.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  437 score 307.3 average score 240.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  438 score 293.8 average score 240.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  439 score 261.3 average score 240.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  440 score 273.5 average score 241.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  441 score 307.6 average score 241.4
# episode  442 score 250.6 average score 241.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  443 score 289.6 average score 241.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  444 score 302.0 average score 241.8
# episode  445 score 263.2 average score 241.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  446 score 278.8 average score 242.0
# episode  447 score 289.4 average score 242.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  448 score 259.7 average score 242.6
# episode  449 score 241.7 average score 242.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  450 score 305.9 average score 242.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  451 score 262.9 average score 243.5
# episode  452 score 258.0 average score 243.2
# episode  453 score 265.5 average score 243.0
# episode  454 score 249.4 average score 243.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  455 score 309.4 average score 244.5
# episode  456 score 253.4 average score 243.9
# episode  457 score 271.5 average score 244.2
# episode  458 score 280.1 average score 244.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  459 score 275.1 average score 246.7
# episode  460 score 217.2 average score 246.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  461 score 281.3 average score 246.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  462 score 259.8 average score 247.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  463 score 321.5 average score 248.1
# episode  464 score 44.6 average score 246.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  465 score 267.2 average score 248.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  466 score 261.2 average score 251.1
# episode  467 score 239.2 average score 250.7
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  468 score 271.8 average score 253.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  469 score 260.8 average score 253.5
# episode  470 score 246.6 average score 253.3
# episode  471 score 270.1 average score 253.5
# episode  472 score 249.9 average score 253.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  473 score 280.2 average score 253.6
# episode  474 score 277.0 average score 253.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  475 score 294.9 average score 254.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  476 score 249.6 average score 254.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  477 score 259.4 average score 254.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  478 score 256.8 average score 254.5
# episode  479 score 254.2 average score 254.1
# episode  480 score 276.8 average score 253.9
# episode  481 score 277.3 average score 254.0
# episode  482 score 292.9 average score 253.7
# episode  483 score 262.4 average score 253.7
# ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  715 score 291.5 average score 273.3
# episode  716 score 279.3 average score 273.2
# episode  717 score 280.5 average score 273.0
# episode  718 score 278.2 average score 272.7
# episode  719 score 289.0 average score 272.7
# episode  720 score 239.5 average score 272.2
# episode  721 score 257.3 average score 271.7
# episode  722 score 278.4 average score 271.7
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  723 score 273.2 average score 274.2
# episode  724 score 246.0 average score 274.2
# episode  725 score 44.2 average score 271.8
# episode  726 score 284.3 average score 271.8
# episode  727 score 269.8 average score 271.5
# episode  728 score 292.9 average score 271.6
# episode  729 score 255.3 average score 271.2
# episode  730 score 251.8 average score 271.3
# episode  731 score 307.7 average score 271.8
# episode  732 score 317.4 average score 272.1
# episode  733 score 296.5 average score 272.0
# episode  734 score 271.4 average score 272.0
# episode  735 score 269.4 average score 272.3
# episode  736 score 276.3 average score 272.2
# episode  737 score 288.0 average score 272.1
# episode  738 score 272.1 average score 272.0
# episode  739 score 250.5 average score 271.7
# episode  740 score 266.9 average score 271.8
# episode  741 score 268.2 average score 271.7
# episode  742 score 266.7 average score 272.0
# episode  743 score 249.1 average score 271.6
# episode  744 score 274.7 average score 271.4
# episode  745 score 306.7 average score 272.1
# episode  746 score 268.8 average score 272.6
# episode  747 score 270.1 average score 272.5
# episode  748 score 270.0 average score 272.7
# episode  749 score 244.6 average score 272.6
# episode  750 score 295.8 average score 272.6
# episode  751 score 266.9 average score 272.4
# episode  752 score 266.2 average score 272.5
# episode  753 score 254.5 average score 272.0
# episode  754 score 270.8 average score 272.3
# episode  755 score 270.6 average score 272.3
# episode  756 score 263.1 average score 271.9
# episode  757 score 291.6 average score 272.3
# episode  758 score 284.2 average score 272.4
# episode  759 score 270.4 average score 272.2
# episode  760 score 273.7 average score 272.5
# episode  761 score 297.2 average score 272.6
# episode  762 score 275.3 average score 272.2
# episode  763 score 298.4 average score 272.5
# episode  764 score 287.1 average score 272.6
# episode  765 score 267.4 average score 272.3
# episode  766 score 279.6 average score 272.4
# episode  767 score 274.5 average score 272.1
# episode  768 score 315.1 average score 272.7
# episode  769 score 284.1 average score 272.9
# episode  770 score 236.8 average score 272.4
# episode  771 score 236.4 average score 272.1
# episode  772 score 289.8 average score 272.2
# episode  773 score 247.6 average score 271.9
# episode  774 score 315.2 average score 272.6
# episode  775 score 249.3 average score 272.1
# episode  776 score 307.7 average score 272.8
# episode  777 score 325.1 average score 273.2
# episode  778 score 259.2 average score 272.8
# episode  779 score 252.7 average score 272.4
# episode  780 score 280.7 average score 272.4
# episode  781 score 312.0 average score 272.9
# episode  782 score 244.4 average score 272.9
# episode  783 score 298.0 average score 273.4
# episode  784 score 246.4 average score 272.8
# episode  785 score 297.4 average score 273.1
# episode  786 score 268.5 average score 272.9
# episode  787 score 273.2 average score 272.7
# episode  788 score 296.3 average score 273.1
# episode  789 score 303.4 average score 273.4
# episode  790 score 280.8 average score 273.5
# episode  791 score 290.0 average score 274.0
# episode  792 score 289.4 average score 274.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  793 score 272.8 average score 274.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  794 score 291.0 average score 274.5
# episode  795 score 281.6 average score 274.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  796 score 279.3 average score 274.7
# episode  797 score 261.5 average score 274.4
# episode  798 score 283.7 average score 274.3
# episode  799 score 249.8 average score 273.8
# episode  800 score 300.6 average score 274.1
# episode  801 score 269.2 average score 274.1
# episode  802 score 298.4 average score 274.5
# episode  803 score 251.4 average score 274.1
# episode  804 score 302.2 average score 274.6
# episode  805 score 277.0 average score 274.5
# episode  806 score 283.3 average score 274.6
# episode  807 score 282.7 average score 274.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  808 score 317.3 average score 274.9
# episode  809 score 269.8 average score 274.7
# episode  810 score 268.5 average score 274.7
# episode  811 score 271.0 average score 274.5
# episode  812 score 266.6 average score 274.7
# episode  813 score 224.3 average score 274.4
# episode  814 score 297.6 average score 274.3
# episode  815 score 253.0 average score 273.9
# episode  816 score 276.4 average score 273.9
# episode  817 score 284.0 average score 273.9
# episode  818 score 263.5 average score 273.8
# episode  819 score 262.3 average score 273.5
# episode  820 score 293.2 average score 274.1
# episode  821 score 304.7 average score 274.5
# episode  822 score 297.3 average score 274.7
# episode  823 score 266.2 average score 274.7
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  824 score 295.9 average score 275.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  825 score 288.9 average score 277.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  826 score 302.8 average score 277.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  827 score 290.9 average score 278.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  828 score 305.6 average score 278.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  829 score 291.2 average score 278.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  830 score 274.4 average score 278.7
# episode  831 score 290.1 average score 278.5
# episode  832 score 288.1 average score 278.2
# episode  833 score 276.7 average score 278.1
# episode  834 score 270.7 average score 278.0
# episode  835 score 267.2 average score 278.0
# episode  836 score 265.8 average score 277.9
# episode  837 score 283.2 average score 277.9
# episode  838 score 270.5 average score 277.9
# episode  839 score 275.0 average score 278.1
# episode  840 score 282.5 average score 278.3
# episode  841 score 237.9 average score 278.0
# episode  842 score 296.5 average score 278.3
# episode  843 score 283.1 average score 278.6
# episode  844 score 284.2 average score 278.7
# episode  845 score 285.0 average score 278.5
# episode  846 score 282.3 average score 278.6
# episode  847 score 270.8 average score 278.6
# episode  848 score 261.9 average score 278.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  849 score 276.9 average score 278.9
# episode  850 score 294.5 average score 278.8
# episode  851 score 265.0 average score 278.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  852 score 280.0 average score 279.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  853 score 312.8 average score 279.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  854 score 284.6 average score 279.7
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  855 score 309.6 average score 280.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  856 score 297.0 average score 280.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  857 score 300.0 average score 280.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  858 score 286.5 average score 280.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  859 score 281.3 average score 280.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  860 score 283.5 average score 280.7
# episode  861 score 286.1 average score 280.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  862 score 299.8 average score 280.9
# episode  863 score 269.2 average score 280.6
# episode  864 score 292.9 average score 280.6
# episode  865 score 287.2 average score 280.8
# episode  866 score 261.8 average score 280.6
# episode  867 score 288.7 average score 280.8
# episode  868 score 276.1 average score 280.4
# episode  869 score 310.6 average score 280.7
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  870 score 263.3 average score 280.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  871 score 318.8 average score 281.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  872 score 308.5 average score 281.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  873 score 304.1 average score 282.5
# episode  874 score 272.4 average score 282.1
# episode  875 score 52.4 average score 280.1
# episode  876 score 302.0 average score 280.1
# episode  877 score 270.8 average score 279.5
# episode  878 score 272.9 average score 279.6
# episode  879 score 311.7 average score 280.2
# episode  880 score 287.1 average score 280.3
# episode  881 score 287.6 average score 280.1
# episode  882 score 293.6 average score 280.5
# episode  883 score 241.5 average score 280.0
# episode  884 score 270.3 average score 280.2
# episode  885 score 270.1 average score 279.9
# episode  886 score 278.7 average score 280.0
# episode  887 score 286.0 average score 280.2
# episode  888 score 278.0 average score 280.0
# episode  889 score 286.8 average score 279.8
# episode  890 score 302.5 average score 280.0
# episode  891 score 295.4 average score 280.1
# episode  892 score 286.1 average score 280.1
# episode  893 score 260.7 average score 279.9
# episode  894 score 286.2 average score 279.9
# episode  895 score 271.1 average score 279.8
# episode  896 score 275.9 average score 279.8
# episode  897 score 263.4 average score 279.8
# episode  898 score 266.7 average score 279.6
# episode  899 score 258.0 average score 279.7
# episode  900 score 294.4 average score 279.6
# episode  901 score 260.1 average score 279.5
# episode  902 score 290.5 average score 279.5
# episode  903 score 295.4 average score 279.9
# episode  904 score 260.3 average score 279.5
# episode  905 score 276.4 average score 279.5
# episode  906 score 280.6 average score 279.4
# episode  907 score 270.2 average score 279.3
# episode  908 score 305.3 average score 279.2
# episode  909 score 283.1 average score 279.3
# episode  910 score 263.3 average score 279.3
# episode  911 score 271.5 average score 279.3
# episode  912 score 261.2 average score 279.2
# episode  913 score 281.8 average score 279.8
# episode  914 score 283.9 average score 279.7
# episode  915 score 267.2 average score 279.8
# episode  916 score 302.2 average score 280.1
# episode  917 score 253.3 average score 279.8
# episode  918 score 268.0 average score 279.8
# episode  919 score 304.2 average score 280.2
# episode  920 score 302.8 average score 280.3
# episode  921 score 285.7 average score 280.1
# episode  922 score 272.6 average score 279.9
# episode  923 score 300.1 average score 280.2
# episode  924 score 274.9 average score 280.0
# episode  925 score 276.6 average score 279.9
# episode  926 score 292.8 average score 279.8
# episode  927 score 259.0 average score 279.5
# episode  928 score 287.0 average score 279.3
# episode  929 score 235.5 average score 278.7
# episode  930 score 269.0 average score 278.7
# episode  931 score 184.6 average score 277.6
# episode  932 score 293.9 average score 277.7
# episode  933 score 228.5 average score 277.2
# episode  934 score 280.8 average score 277.3
# episode  935 score 294.0 average score 277.6
# episode  936 score 309.3 average score 278.0
# episode  937 score 289.4 average score 278.1
# episode  938 score 256.7 average score 277.9
# episode  939 score 243.8 average score 277.6
# episode  940 score 283.5 average score 277.6
# episode  941 score 234.4 average score 277.6
# episode  942 score 289.4 average score 277.5
# episode  943 score 303.8 average score 277.7
# episode  944 score 280.6 average score 277.7
# episode  945 score 274.2 average score 277.6
# episode  946 score 300.7 average score 277.8
# episode  947 score 285.8 average score 277.9
# episode  948 score 279.7 average score 278.1
# episode  949 score 243.8 average score 277.8
# episode  950 score 275.5 average score 277.6
# episode  951 score 278.3 average score 277.7
# episode  952 score 279.5 average score 277.7
# episode  953 score 268.7 average score 277.3
# episode  954 score 276.6 average score 277.2
# episode  955 score 253.9 average score 276.6
# episode  956 score 298.7 average score 276.6
# episode  957 score 281.7 average score 276.5
# episode  958 score 270.8 average score 276.3
# episode  959 score 249.1 average score 276.0
# episode  960 score 233.9 average score 275.5
# episode  961 score 261.5 average score 275.2
# episode  962 score 269.7 average score 274.9
# episode  963 score 291.1 average score 275.1
# episode  964 score 308.8 average score 275.3
# episode  965 score 299.0 average score 275.4
# episode  966 score 255.7 average score 275.4
# episode  967 score 256.6 average score 275.0
# episode  968 score 273.6 average score 275.0
# episode  969 score 275.5 average score 274.7
# episode  970 score 279.4 average score 274.8
# episode  971 score 308.8 average score 274.7
# episode  972 score 291.0 average score 274.6
# episode  973 score 252.0 average score 274.0
