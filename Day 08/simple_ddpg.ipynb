# %% [markdown]
# <a href="https://colab.research.google.com/github/minjeong-kim-git/HUFS-RL-2022/blob/main/Day%2008/simple_ddpg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir DDPG

# %%
import os
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

class OUActionNoise(object):
    def __init__(self, mu, sigma=0.15, theta=.2, dt=1e-2, x0=None):
        self.theta = theta
        self.mu = mu
        self.sigma = sigma
        self.dt = dt
        self.x0 = x0
        self.reset()

    def __call__(self):
        x = self.x_prev + self.theta * (self.mu - self.x_prev) * self.dt + \
            self.sigma * np.sqrt(self.dt) * np.random.normal(size=self.mu.shape)
        self.x_prev = x
        return x

    def reset(self):
        self.x_prev = self.x0 if self.x0 is not None else np.zeros_like(self.mu)

    def __repr__(self):
        return 'OrnsteinUhlenbeckActionNoise(mu={}, sigma={})'.format(
                                                            self.mu, self.sigma)

class ReplayBuffer(object):
    def __init__(self, max_size, input_shape, n_actions):
        self.mem_size = max_size
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size, *input_shape))
        self.new_state_memory = np.zeros((self.mem_size, *input_shape))
        self.action_memory = np.zeros((self.mem_size, n_actions))
        self.reward_memory = np.zeros(self.mem_size)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.float32)

    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.terminal_memory[index] = 1 - done
        self.mem_cntr += 1

    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)

        batch = np.random.choice(max_mem, batch_size)

        states = self.state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        states_ = self.new_state_memory[batch]
        terminal = self.terminal_memory[batch]

        return states, actions, rewards, states_, terminal

class CriticNetwork(nn.Module):
    def __init__(self, beta, input_dims, fc1_dims, fc2_dims, n_actions, name,
                 chkpt_dir='DDPG'):
        super(CriticNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.checkpoint_file = os.path.join(chkpt_dir,name+'_ddpg')
        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        f1 = 1./np.sqrt(self.fc1.weight.data.size()[0])
        T.nn.init.uniform_(self.fc1.weight.data, -f1, f1)
        T.nn.init.uniform_(self.fc1.bias.data, -f1, f1)
        #self.fc1.weight.data.uniform_(-f1, f1)
        #self.fc1.bias.data.uniform_(-f1, f1)
        self.bn1 = nn.LayerNorm(self.fc1_dims)

        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        f2 = 1./np.sqrt(self.fc2.weight.data.size()[0])
        #f2 = 0.002
        T.nn.init.uniform_(self.fc2.weight.data, -f2, f2)
        T.nn.init.uniform_(self.fc2.bias.data, -f2, f2)
        #self.fc2.weight.data.uniform_(-f2, f2)
        #self.fc2.bias.data.uniform_(-f2, f2)
        self.bn2 = nn.LayerNorm(self.fc2_dims)

        self.action_value = nn.Linear(self.n_actions, self.fc2_dims)
        f3 = 0.003
        self.q = nn.Linear(self.fc2_dims, 1)
        T.nn.init.uniform_(self.q.weight.data, -f3, f3)
        T.nn.init.uniform_(self.q.bias.data, -f3, f3)
        #self.q.weight.data.uniform_(-f3, f3)
        #self.q.bias.data.uniform_(-f3, f3)

        self.optimizer = optim.Adam(self.parameters(), lr=beta)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cuda:1')

        self.to(self.device)

    def forward(self, state, action):
        state_value = self.fc1(state)
        state_value = self.bn1(state_value)
        state_value = F.relu(state_value)
        state_value = self.fc2(state_value)
        state_value = self.bn2(state_value)

        action_value = F.relu(self.action_value(action))
        state_action_value = F.relu(T.add(state_value, action_value))
        state_action_value = self.q(state_action_value)

        return state_action_value

    def save_checkpoint(self):
        print('... saving checkpoint ...')
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        print('... loading checkpoint ...')
        self.load_state_dict(T.load(self.checkpoint_file))

class ActorNetwork(nn.Module):
    def __init__(self, alpha, input_dims, fc1_dims, fc2_dims, n_actions, name,
                 chkpt_dir='DDPG'):
        super(ActorNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.checkpoint_file = os.path.join(chkpt_dir,name+'_ddpg')
        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        f1 = 1./np.sqrt(self.fc1.weight.data.size()[0])
        T.nn.init.uniform_(self.fc1.weight.data, -f1, f1)
        T.nn.init.uniform_(self.fc1.bias.data, -f1, f1)
        #self.fc1.weight.data.uniform_(-f1, f1)
        #self.fc1.bias.data.uniform_(-f1, f1)
        self.bn1 = nn.LayerNorm(self.fc1_dims)

        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        #f2 = 0.002
        f2 = 1./np.sqrt(self.fc2.weight.data.size()[0])
        T.nn.init.uniform_(self.fc2.weight.data, -f2, f2)
        T.nn.init.uniform_(self.fc2.bias.data, -f2, f2)
        #self.fc2.weight.data.uniform_(-f2, f2)
        #self.fc2.bias.data.uniform_(-f2, f2)
        self.bn2 = nn.LayerNorm(self.fc2_dims)

        #f3 = 0.004
        f3 = 0.003
        self.mu = nn.Linear(self.fc2_dims, self.n_actions)
        T.nn.init.uniform_(self.mu.weight.data, -f3, f3)
        T.nn.init.uniform_(self.mu.bias.data, -f3, f3)
        #self.mu.weight.data.uniform_(-f3, f3)
        #self.mu.bias.data.uniform_(-f3, f3)

        self.optimizer = optim.Adam(self.parameters(), lr=alpha)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cuda:1')

        self.to(self.device)

    def forward(self, state):
        x = self.fc1(state)
        x = self.bn1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = T.tanh(self.mu(x))

        return x

    def save_checkpoint(self):
        print('... saving checkpoint ...')
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        print('... loading checkpoint ...')
        self.load_state_dict(T.load(self.checkpoint_file))

class Agent(object):
    def __init__(self, alpha, beta, input_dims, tau, env, gamma=0.99,
                 n_actions=2, max_size=1000000, layer1_size=400,
                 layer2_size=300, batch_size=64):
        self.gamma = gamma
        self.tau = tau
        self.memory = ReplayBuffer(max_size, input_dims, n_actions)
        self.batch_size = batch_size

        self.actor = ActorNetwork(alpha, input_dims, layer1_size,
                                  layer2_size, n_actions=n_actions,
                                  name='Actor')
        self.critic = CriticNetwork(beta, input_dims, layer1_size,
                                    layer2_size, n_actions=n_actions,
                                    name='Critic')

        self.target_actor = ActorNetwork(alpha, input_dims, layer1_size,
                                         layer2_size, n_actions=n_actions,
                                         name='TargetActor')
        self.target_critic = CriticNetwork(beta, input_dims, layer1_size,
                                           layer2_size, n_actions=n_actions,
                                           name='TargetCritic')

        self.noise = OUActionNoise(mu=np.zeros(n_actions))

        self.update_network_parameters(tau=1)

    def choose_action(self, observation):
        self.actor.eval()
        observation = T.tensor(observation, dtype=T.float).to(self.actor.device)
        mu = self.actor.forward(observation).to(self.actor.device)
        mu_prime = mu + T.tensor(self.noise(),
                                 dtype=T.float).to(self.actor.device)
        self.actor.train()
        return mu_prime.cpu().detach().numpy()


    def remember(self, state, action, reward, new_state, done):
        self.memory.store_transition(state, action, reward, new_state, done)

    def learn(self):
        if self.memory.mem_cntr < self.batch_size:
            return
        state, action, reward, new_state, done = \
                                      self.memory.sample_buffer(self.batch_size)

        reward = T.tensor(reward, dtype=T.float).to(self.critic.device)
        done = T.tensor(done).to(self.critic.device)
        new_state = T.tensor(new_state, dtype=T.float).to(self.critic.device)
        action = T.tensor(action, dtype=T.float).to(self.critic.device)
        state = T.tensor(state, dtype=T.float).to(self.critic.device)

        self.target_actor.eval()
        self.target_critic.eval()
        self.critic.eval()
        target_actions = self.target_actor.forward(new_state)
        critic_value_ = self.target_critic.forward(new_state, target_actions)
        critic_value = self.critic.forward(state, action)

        target = []
        for j in range(self.batch_size):
            target.append(reward[j] + self.gamma*critic_value_[j]*done[j])
        target = T.tensor(target).to(self.critic.device)
        target = target.view(self.batch_size, 1)

        self.critic.train()
        self.critic.optimizer.zero_grad()
        critic_loss = F.mse_loss(target, critic_value)
        critic_loss.backward()
        self.critic.optimizer.step()

        self.critic.eval()
        self.actor.optimizer.zero_grad()
        mu = self.actor.forward(state)
        self.actor.train()
        actor_loss = -self.critic.forward(state, mu)
        actor_loss = T.mean(actor_loss)
        actor_loss.backward()
        self.actor.optimizer.step()

        self.update_network_parameters()

    def update_network_parameters(self, tau=None):
        if tau is None:
            tau = self.tau

        actor_params = self.actor.named_parameters()
        critic_params = self.critic.named_parameters()
        target_actor_params = self.target_actor.named_parameters()
        target_critic_params = self.target_critic.named_parameters()

        critic_state_dict = dict(critic_params)
        actor_state_dict = dict(actor_params)
        target_critic_dict = dict(target_critic_params)
        target_actor_dict = dict(target_actor_params)

        for name in critic_state_dict:
            critic_state_dict[name] = tau*critic_state_dict[name].clone() + \
                                      (1-tau)*target_critic_dict[name].clone()

        self.target_critic.load_state_dict(critic_state_dict)

        for name in actor_state_dict:
            actor_state_dict[name] = tau*actor_state_dict[name].clone() + \
                                      (1-tau)*target_actor_dict[name].clone()
        self.target_actor.load_state_dict(actor_state_dict)

        """
        #Verify that the copy assignment worked correctly
        target_actor_params = self.target_actor.named_parameters()
        target_critic_params = self.target_critic.named_parameters()

        critic_state_dict = dict(target_critic_params)
        actor_state_dict = dict(target_actor_params)
        print('\nActor Networks', tau)
        for name, param in self.actor.named_parameters():
            print(name, T.equal(param, actor_state_dict[name]))
        print('\nCritic Networks', tau)
        for name, param in self.critic.named_parameters():
            print(name, T.equal(param, critic_state_dict[name]))
        input()
        """
    def save_models(self):
        self.actor.save_checkpoint()
        self.target_actor.save_checkpoint()
        self.critic.save_checkpoint()
        self.target_critic.save_checkpoint()

    def load_models(self):
        self.actor.load_checkpoint()
        self.target_actor.load_checkpoint()
        self.critic.load_checkpoint()
        self.target_critic.load_checkpoint()

    def check_actor_params(self):
        current_actor_params = self.actor.named_parameters()
        current_actor_dict = dict(current_actor_params)
        original_actor_dict = dict(self.original_actor.named_parameters())
        original_critic_dict = dict(self.original_critic.named_parameters())
        current_critic_params = self.critic.named_parameters()
        current_critic_dict = dict(current_critic_params)
        print('Checking Actor parameters')

        for param in current_actor_dict:
            print(param, T.equal(original_actor_dict[param], current_actor_dict[param]))
        print('Checking critic parameters')
        for param in current_critic_dict:
            print(param, T.equal(original_critic_dict[param], current_critic_dict[param]))
        input()

# %%
import matplotlib.pyplot as plt 
import numpy as np

def plotLearning(scores, filename, x=None, window=5):   
    N = len(scores)
    running_avg = np.empty(N)
    for t in range(N):
	    running_avg[t] = np.mean(scores[max(0, t-window):(t+1)])
    if x is None:
        x = [i for i in range(N)]
    plt.ylabel('Score')       
    plt.xlabel('Game')                     
    plt.plot(x, running_avg)
    plt.savefig(filename)

# %%
# !pip install box2d-py
# !pip install gym[Box_2D]
# Out:
# Collecting box2d-py
#   Downloading box2d_py-2.3.8-cp37-cp37m-manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 5.4 MB/s
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8
# Requirement already satisfied: gym[Box_2D] in /usr/local/lib/python3.7/dist-packages (0.17.3)
# WARNING: gym 0.17.3 does not provide the extra 'box_2d'
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.4.1)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.5.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.19.5)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym[Box_2D]) (0.16.0)

# %%
import gym
import numpy as np

env = gym.make('LunarLanderContinuous-v2')
agent = Agent(alpha=0.000025, beta=0.00025, input_dims=[8], tau=0.001, env=env,
              batch_size=64,  layer1_size=400, layer2_size=300, n_actions=2)

agent.load_models()
np.random.seed(0)

score_history = []
for i in range(1000):
    obs = env.reset()
    done = False
    score = 0
    while not done:
        act = agent.choose_action(obs)
        new_state, reward, done, info = env.step(act)
        agent.remember(obs, act, reward, new_state, int(done))
        agent.learn()
        score += reward
        obs = new_state
        env.render()
    score_history.append(score)

    if i % 25 == 0:
       agent.save_models()

    print('episode ', i, 'score %.2f' % score,
          'trailing 100 games avg %.3f' % np.mean(score_history[-100:]))

filename = 'LunarLander-alpha000025-beta00025-400-300.png'
plotLearning(score_history, filename, window=100)
# Out:
# episode  0 score -458.58 trailing 100 games avg -458.583
# episode  1 score -127.76 trailing 100 games avg -293.171
# episode  2 score -373.11 trailing 100 games avg -319.817
# episode  3 score -541.59 trailing 100 games avg -375.260
# episode  4 score -539.62 trailing 100 games avg -408.133
# episode  5 score -338.01 trailing 100 games avg -396.445
# episode  6 score -311.84 trailing 100 games avg -384.358
# episode  7 score -140.70 trailing 100 games avg -353.901
# episode  8 score -171.17 trailing 100 games avg -333.598
# episode  9 score -104.34 trailing 100 games avg -310.673
# episode  10 score -755.56 trailing 100 games avg -351.117
# episode  11 score -777.48 trailing 100 games avg -386.647
# episode  12 score -649.24 trailing 100 games avg -406.846
# episode  13 score -674.12 trailing 100 games avg -425.937
# episode  14 score -663.09 trailing 100 games avg -441.747
# episode  15 score -589.29 trailing 100 games avg -450.968
# episode  16 score -202.55 trailing 100 games avg -436.356
# episode  17 score -356.71 trailing 100 games avg -431.931
# episode  18 score -271.95 trailing 100 games avg -423.511
# episode  19 score 11.16 trailing 100 games avg -401.777
# episode  20 score -85.84 trailing 100 games avg -386.732
# episode  21 score -191.80 trailing 100 games avg -377.872
# episode  22 score -262.14 trailing 100 games avg -372.840
# episode  23 score -328.20 trailing 100 games avg -370.980
# episode  24 score -385.86 trailing 100 games avg -371.575
# episode  25 score -276.56 trailing 100 games avg -367.921
# episode  26 score -353.18 trailing 100 games avg -367.375
# episode  27 score -303.66 trailing 100 games avg -365.100
# episode  28 score -286.15 trailing 100 games avg -362.377
# episode  29 score -332.51 trailing 100 games avg -361.381
# episode  30 score -249.56 trailing 100 games avg -357.774
# episode  31 score -281.50 trailing 100 games avg -355.390
# episode  32 score -300.68 trailing 100 games avg -353.732
# episode  33 score -444.11 trailing 100 games avg -356.391
# episode  34 score -280.84 trailing 100 games avg -354.232
# episode  35 score -263.53 trailing 100 games avg -351.713
# episode  36 score -337.72 trailing 100 games avg -351.334
# episode  37 score -362.09 trailing 100 games avg -351.618
# episode  38 score -482.71 trailing 100 games avg -354.979
# episode  39 score -375.99 trailing 100 games avg -355.504
# episode  40 score -466.61 trailing 100 games avg -358.214
# episode  41 score -461.76 trailing 100 games avg -360.680
# episode  42 score -599.72 trailing 100 games avg -366.239
# episode  43 score -509.38 trailing 100 games avg -369.492
# episode  44 score -559.52 trailing 100 games avg -373.715
# episode  45 score -508.54 trailing 100 games avg -376.646
# episode  46 score -366.81 trailing 100 games avg -376.436
# episode  47 score -580.00 trailing 100 games avg -380.677
# episode  48 score -236.04 trailing 100 games avg -377.725
# episode  49 score -329.51 trailing 100 games avg -376.761
# episode  50 score -328.04 trailing 100 games avg -375.806
# episode  51 score -116.54 trailing 100 games avg -370.820
# episode  52 score -234.92 trailing 100 games avg -368.256
# episode  53 score -120.76 trailing 100 games avg -363.672
# episode  54 score -104.42 trailing 100 games avg -358.959
# episode  55 score -205.46 trailing 100 games avg -356.218
# episode  56 score -223.16 trailing 100 games avg -353.883
# episode  57 score -236.68 trailing 100 games avg -351.863
# episode  58 score -213.89 trailing 100 games avg -349.524
# episode  59 score -102.98 trailing 100 games avg -345.415
# episode  60 score -176.77 trailing 100 games avg -342.650
# episode  61 score -242.35 trailing 100 games avg -341.033
# episode  62 score -93.70 trailing 100 games avg -337.107
# episode  63 score -113.67 trailing 100 games avg -333.616
# episode  64 score -67.75 trailing 100 games avg -329.525
# episode  65 score -116.99 trailing 100 games avg -326.305
# episode  66 score -251.07 trailing 100 games avg -325.182
# episode  67 score -212.96 trailing 100 games avg -323.532
# episode  68 score -224.46 trailing 100 games avg -322.096
# episode  69 score -158.79 trailing 100 games avg -319.763
# episode  70 score -119.96 trailing 100 games avg -316.949
# episode  71 score -72.03 trailing 100 games avg -313.547
# episode  72 score -92.43 trailing 100 games avg -310.518
# episode  73 score -83.19 trailing 100 games avg -307.446
# episode  74 score -98.12 trailing 100 games avg -304.655
# episode  75 score -117.67 trailing 100 games avg -302.195
# episode  76 score -150.58 trailing 100 games avg -300.226
# episode  77 score -135.18 trailing 100 games avg -298.110
# episode  78 score -113.14 trailing 100 games avg -295.768
# episode  79 score -107.62 trailing 100 games avg -293.416
# episode  80 score -112.64 trailing 100 games avg -291.185
# episode  81 score -213.91 trailing 100 games avg -290.242
# episode  82 score -279.21 trailing 100 games avg -290.109
# episode  83 score -124.16 trailing 100 games avg -288.134
# episode  84 score -186.79 trailing 100 games avg -286.941
# episode  85 score -204.32 trailing 100 games avg -285.981
# episode  86 score -97.18 trailing 100 games avg -283.811
# episode  87 score -199.55 trailing 100 games avg -282.853
# episode  88 score -242.33 trailing 100 games avg -282.398
# episode  89 score -271.75 trailing 100 games avg -282.280
# episode  90 score -297.31 trailing 100 games avg -282.445
# episode  91 score -171.00 trailing 100 games avg -281.233
# episode  92 score -182.90 trailing 100 games avg -280.176
# episode  93 score -282.01 trailing 100 games avg -280.196
# episode  94 score -307.45 trailing 100 games avg -280.482
# episode  95 score -173.00 trailing 100 games avg -279.363
# episode  96 score -89.71 trailing 100 games avg -277.408
# episode  97 score -150.72 trailing 100 games avg -276.115
# episode  98 score -233.02 trailing 100 games avg -275.680
# episode  99 score -153.33 trailing 100 games avg -274.456
# episode  100 score -78.10 trailing 100 games avg -270.651
# episode  101 score -278.18 trailing 100 games avg -272.156
# episode  102 score -424.84 trailing 100 games avg -272.673
# episode  103 score -185.85 trailing 100 games avg -269.115
# episode  104 score -234.81 trailing 100 games avg -266.067
# episode  105 score -239.41 trailing 100 games avg -265.081
# episode  106 score -236.18 trailing 100 games avg -264.325
# episode  107 score -277.81 trailing 100 games avg -265.696
# episode  108 score -329.60 trailing 100 games avg -267.280
# episode  109 score -284.61 trailing 100 games avg -269.083
# episode  110 score -220.41 trailing 100 games avg -263.731
# episode  111 score -114.47 trailing 100 games avg -257.101
# episode  112 score -367.01 trailing 100 games avg -254.279
# episode  113 score -311.41 trailing 100 games avg -250.652
# episode  114 score -201.04 trailing 100 games avg -246.031
# episode  115 score -305.75 trailing 100 games avg -243.196
# episode  116 score -313.01 trailing 100 games avg -244.301
# episode  117 score -310.48 trailing 100 games avg -243.838
# episode  118 score -274.08 trailing 100 games avg -243.860
# episode  119 score -238.66 trailing 100 games avg -246.358
# episode  120 score -270.89 trailing 100 games avg -248.208
# episode  121 score -204.37 trailing 100 games avg -248.334
# episode  122 score -319.23 trailing 100 games avg -248.905
# episode  123 score -141.78 trailing 100 games avg -247.041
# episode  124 score -181.90 trailing 100 games avg -245.001
# episode  125 score -230.98 trailing 100 games avg -244.545
# episode  126 score -236.16 trailing 100 games avg -243.375
# episode  127 score -245.60 trailing 100 games avg -242.795
# episode  128 score -306.79 trailing 100 games avg -243.001
# episode  129 score -216.79 trailing 100 games avg -241.844
# episode  130 score -190.10 trailing 100 games avg -241.249
# episode  131 score -206.26 trailing 100 games avg -240.497
# episode  132 score -139.83 trailing 100 games avg -238.888
# episode  133 score -202.89 trailing 100 games avg -236.476
# episode  134 score -155.50 trailing 100 games avg -235.223
# episode  135 score -176.08 trailing 100 games avg -234.348
# episode  136 score -155.30 trailing 100 games avg -232.524
# episode  137 score -150.61 trailing 100 games avg -230.409
# episode  138 score -159.54 trailing 100 games avg -227.178
# episode  139 score -119.28 trailing 100 games avg -224.611
# episode  140 score -160.00 trailing 100 games avg -221.544
# episode  141 score -192.38 trailing 100 games avg -218.851
# episode  142 score -197.68 trailing 100 games avg -214.830
# episode  143 score -233.90 trailing 100 games avg -212.075
# episode  144 score -156.11 trailing 100 games avg -208.041
# episode  145 score -251.55 trailing 100 games avg -205.472
# episode  146 score -291.81 trailing 100 games avg -204.722
# episode  147 score -64.73 trailing 100 games avg -199.569
# episode  148 score -217.45 trailing 100 games avg -199.383
# episode  149 score -259.00 trailing 100 games avg -198.678
# episode  150 score -358.87 trailing 100 games avg -198.986
# episode  151 score -235.15 trailing 100 games avg -200.172
# episode  152 score -181.46 trailing 100 games avg -199.638
# episode  153 score -216.62 trailing 100 games avg -200.596
# episode  154 score -274.62 trailing 100 games avg -202.298
# episode  155 score -235.97 trailing 100 games avg -202.603
# episode  156 score -210.27 trailing 100 games avg -202.474
# episode  157 score -81.08 trailing 100 games avg -200.918
# episode  158 score -327.54 trailing 100 games avg -202.055
# episode  159 score -177.17 trailing 100 games avg -202.797
# episode  160 score -285.39 trailing 100 games avg -203.883
# episode  161 score -354.05 trailing 100 games avg -205.000
# episode  162 score -33.46 trailing 100 games avg -204.397
# episode  163 score -140.45 trailing 100 games avg -204.665
# episode  164 score -165.94 trailing 100 games avg -205.647
# episode  165 score -189.90 trailing 100 games avg -206.376
# episode  166 score -199.84 trailing 100 games avg -205.864
# episode  167 score -164.19 trailing 100 games avg -205.376
# episode  168 score -183.99 trailing 100 games avg -204.972
# episode  169 score -171.01 trailing 100 games avg -205.094
# episode  170 score -158.17 trailing 100 games avg -205.476
# episode  171 score -239.26 trailing 100 games avg -207.148
# episode  172 score -191.45 trailing 100 games avg -208.138
# episode  173 score -184.18 trailing 100 games avg -209.148
# episode  174 score -265.73 trailing 100 games avg -210.824
# episode  175 score -303.36 trailing 100 games avg -212.681
# episode  176 score -188.76 trailing 100 games avg -213.063
# episode  177 score -19.55 trailing 100 games avg -211.907
# episode  178 score -208.84 trailing 100 games avg -212.864
# episode  179 score -62.83 trailing 100 games avg -212.416
# episode  180 score -140.48 trailing 100 games avg -212.694
# episode  181 score -176.92 trailing 100 games avg -212.324
# episode  182 score -162.79 trailing 100 games avg -211.160
# episode  183 score -187.73 trailing 100 games avg -211.796
# episode  184 score -179.29 trailing 100 games avg -211.721
# episode  185 score -136.25 trailing 100 games avg -211.040
# episode  186 score -123.04 trailing 100 games avg -211.299
# episode  187 score -201.87 trailing 100 games avg -211.322
# episode  188 score -113.91 trailing 100 games avg -210.038
# episode  189 score -310.28 trailing 100 games avg -210.423
# episode  190 score -18.96 trailing 100 games avg -207.640
# episode  191 score -173.62 trailing 100 games avg -207.666
# episode  192 score -156.46 trailing 100 games avg -207.401
# episode  193 score -155.05 trailing 100 games avg -206.132
# episode  194 score -143.96 trailing 100 games avg -204.497
# episode  195 score -9.00 trailing 100 games avg -202.857
# episode  196 score -166.52 trailing 100 games avg -203.625
# episode  197 score -36.30 trailing 100 games avg -202.481
# episode  198 score -173.23 trailing 100 games avg -201.883
# episode  199 score -109.71 trailing 100 games avg -201.447
# episode  200 score -284.11 trailing 100 games avg -203.507
# episode  201 score -149.59 trailing 100 games avg -202.221
# episode  202 score 28.38 trailing 100 games avg -197.689
# episode  203 score -121.33 trailing 100 games avg -197.043
# episode  204 score -52.32 trailing 100 games avg -195.218
# episode  205 score -373.44 trailing 100 games avg -196.559
# episode  206 score -137.14 trailing 100 games avg -195.568
# episode  207 score -18.53 trailing 100 games avg -192.975
# episode  208 score -339.20 trailing 100 games avg -193.071
# episode  209 score -153.04 trailing 100 games avg -191.756
# episode  210 score -173.41 trailing 100 games avg -191.286
# episode  211 score -107.10 trailing 100 games avg -191.212
# episode  212 score -150.74 trailing 100 games avg -189.049
# episode  213 score -55.51 trailing 100 games avg -186.491
# episode  214 score -108.51 trailing 100 games avg -185.565
# episode  215 score -240.42 trailing 100 games avg -184.912
# episode  216 score -201.82 trailing 100 games avg -183.800
# episode  217 score -235.07 trailing 100 games avg -183.046
# episode  218 score -284.32 trailing 100 games avg -183.148
# episode  219 score -115.88 trailing 100 games avg -181.921
# episode  220 score -275.40 trailing 100 games avg -181.966
# episode  221 score -67.59 trailing 100 games avg -180.598
# episode  222 score -102.19 trailing 100 games avg -178.428
# episode  223 score -106.28 trailing 100 games avg -178.073
# episode  224 score -4.50 trailing 100 games avg -176.299
# episode  225 score -199.64 trailing 100 games avg -175.985
# episode  226 score -174.73 trailing 100 games avg -175.371
# episode  227 score -28.31 trailing 100 games avg -173.198
# episode  228 score -161.11 trailing 100 games avg -171.741
# episode  229 score -97.28 trailing 100 games avg -170.546
# episode  230 score 3.71 trailing 100 games avg -168.608
# episode  231 score -222.64 trailing 100 games avg -168.772
# episode  232 score -306.84 trailing 100 games avg -170.442
# episode  233 score -218.41 trailing 100 games avg -170.597
# episode  234 score -78.27 trailing 100 games avg -169.824
# episode  235 score -174.62 trailing 100 games avg -169.810
# episode  236 score 12.90 trailing 100 games avg -168.128
# episode  237 score -107.37 trailing 100 games avg -167.695
# episode  238 score -52.92 trailing 100 games avg -166.629
# episode  239 score -109.32 trailing 100 games avg -166.530
# episode  240 score -84.24 trailing 100 games avg -165.772
# episode  241 score -83.28 trailing 100 games avg -164.681
# episode  242 score -169.24 trailing 100 games avg -164.397
# episode  243 score -71.09 trailing 100 games avg -162.769
# episode  244 score -112.98 trailing 100 games avg -162.337
# episode  245 score -102.20 trailing 100 games avg -160.844
# episode  246 score -88.40 trailing 100 games avg -158.810
# episode  247 score -124.94 trailing 100 games avg -159.412
# episode  248 score -109.53 trailing 100 games avg -158.333
# episode  249 score -230.85 trailing 100 games avg -158.051
# episode  250 score -208.50 trailing 100 games avg -156.547
# episode  251 score -126.20 trailing 100 games avg -155.458
# episode  252 score -127.44 trailing 100 games avg -154.918
# episode  253 score -186.24 trailing 100 games avg -154.614
# episode  254 score -300.39 trailing 100 games avg -154.872
# episode  255 score -424.92 trailing 100 games avg -156.761
# episode  256 score -50.89 trailing 100 games avg -155.167
# episode  257 score -269.88 trailing 100 games avg -157.055
# episode  258 score -104.80 trailing 100 games avg -154.828
# episode  259 score -197.91 trailing 100 games avg -155.035
# episode  260 score -260.21 trailing 100 games avg -154.783
# episode  261 score -163.99 trailing 100 games avg -152.883
# episode  262 score -99.39 trailing 100 games avg -153.542
# episode  263 score -103.91 trailing 100 games avg -153.177
# episode  264 score -69.75 trailing 100 games avg -152.215
# episode  265 score -37.21 trailing 100 games avg -150.688
# episode  266 score -42.96 trailing 100 games avg -149.119
# episode  267 score -137.84 trailing 100 games avg -148.856
# episode  268 score -184.51 trailing 100 games avg -148.861
# episode  269 score -189.56 trailing 100 games avg -149.046
# episode  270 score -179.83 trailing 100 games avg -149.263
# episode  271 score -118.46 trailing 100 games avg -148.055
# episode  272 score -212.00 trailing 100 games avg -148.260
# episode  273 score -195.04 trailing 100 games avg -148.369
# episode  274 score -260.30 trailing 100 games avg -148.315
# episode  275 score -246.72 trailing 100 games avg -147.748
# episode  276 score -97.56 trailing 100 games avg -146.836
# episode  277 score -61.84 trailing 100 games avg -147.259
# episode  278 score -81.84 trailing 100 games avg -145.989
# episode  279 score -21.92 trailing 100 games avg -145.580
# episode  280 score 21.16 trailing 100 games avg -143.964
# episode  281 score -0.98 trailing 100 games avg -142.204
# episode  282 score -240.60 trailing 100 games avg -142.982
# episode  283 score -95.12 trailing 100 games avg -142.056
# episode  284 score -34.34 trailing 100 games avg -140.607
# episode  285 score -86.73 trailing 100 games avg -140.112
# episode  286 score -11.99 trailing 100 games avg -139.001
# episode  287 score -49.72 trailing 100 games avg -137.480
# episode  288 score -84.56 trailing 100 games avg -137.186
# episode  289 score -65.19 trailing 100 games avg -134.735
# episode  290 score -119.37 trailing 100 games avg -135.739
# episode  291 score -44.44 trailing 100 games avg -134.447
# episode  292 score -103.51 trailing 100 games avg -133.918
# episode  293 score -75.25 trailing 100 games avg -133.120
# episode  294 score -90.76 trailing 100 games avg -132.588
# episode  295 score -302.42 trailing 100 games avg -135.522
# episode  296 score -176.13 trailing 100 games avg -135.618
# episode  297 score -160.77 trailing 100 games avg -136.863
# episode  298 score -158.45 trailing 100 games avg -136.715
# episode  299 score -117.76 trailing 100 games avg -136.796
# episode  300 score -86.28 trailing 100 games avg -134.817
# episode  301 score -49.49 trailing 100 games avg -133.816
# episode  302 score -62.73 trailing 100 games avg -134.728
# episode  303 score -31.53 trailing 100 games avg -133.830
# episode  304 score -15.53 trailing 100 games avg -133.462
# episode  305 score -141.89 trailing 100 games avg -131.146
# episode  306 score -74.75 trailing 100 games avg -130.522
# episode  307 score -91.50 trailing 100 games avg -131.252
# episode  308 score -67.80 trailing 100 games avg -128.538
# episode  309 score -43.16 trailing 100 games avg -127.439
# episode  310 score -90.82 trailing 100 games avg -126.613
# episode  311 score -124.95 trailing 100 games avg -126.792
# episode  312 score -77.14 trailing 100 games avg -126.056
# episode  313 score -81.78 trailing 100 games avg -126.318
# episode  314 score 3.18 trailing 100 games avg -125.201
# episode  315 score -28.36 trailing 100 games avg -123.081
# episode  316 score -218.79 trailing 100 games avg -123.251
# episode  317 score -145.53 trailing 100 games avg -122.355
# episode  318 score -577.46 trailing 100 games avg -125.287
# episode  319 score -265.75 trailing 100 games avg -126.785
# episode  320 score -292.38 trailing 100 games avg -126.955
# episode  321 score -266.11 trailing 100 games avg -128.940
# episode  322 score -51.00 trailing 100 games avg -128.428
# episode  323 score -74.90 trailing 100 games avg -128.115
# episode  324 score 32.76 trailing 100 games avg -127.742
# episode  325 score -41.50 trailing 100 games avg -126.161
# episode  326 score -101.10 trailing 100 games avg -125.424
# episode  327 score -84.11 trailing 100 games avg -125.982
# episode  328 score -33.54 trailing 100 games avg -124.707
# episode  329 score -59.70 trailing 100 games avg -124.331
# episode  330 score -226.26 trailing 100 games avg -126.631
# episode  331 score 18.16 trailing 100 games avg -124.223
# episode  332 score -160.18 trailing 100 games avg -122.756
# episode  333 score -40.88 trailing 100 games avg -120.981
# episode  334 score 6.47 trailing 100 games avg -120.133
# episode  335 score -84.25 trailing 100 games avg -119.230
# episode  336 score -244.19 trailing 100 games avg -121.801
# episode  337 score 208.20 trailing 100 games avg -118.645
# episode  338 score -62.68 trailing 100 games avg -118.742
# episode  339 score -35.62 trailing 100 games avg -118.005
# episode  340 score -92.84 trailing 100 games avg -118.091
# episode  341 score -2.99 trailing 100 games avg -117.288
# episode  342 score 3.73 trailing 100 games avg -115.559
# episode  343 score -232.97 trailing 100 games avg -117.178
# episode  344 score -75.41 trailing 100 games avg -116.802
# episode  345 score -284.07 trailing 100 games avg -118.620
# episode  346 score -263.05 trailing 100 games avg -120.367
# episode  347 score -163.99 trailing 100 games avg -120.758
# episode  348 score -292.21 trailing 100 games avg -122.584
# episode  349 score -233.64 trailing 100 games avg -122.612
# episode  350 score -90.39 trailing 100 games avg -121.431
# episode  351 score -127.42 trailing 100 games avg -121.443
# episode  352 score -101.22 trailing 100 games avg -121.181
# episode  353 score -19.85 trailing 100 games avg -119.517
# episode  354 score -71.17 trailing 100 games avg -117.225
# episode  355 score -144.83 trailing 100 games avg -114.424
# episode  356 score -200.77 trailing 100 games avg -115.923
# episode  357 score -267.54 trailing 100 games avg -115.900
# episode  358 score -98.35 trailing 100 games avg -115.835
# episode  359 score -171.89 trailing 100 games avg -115.575
# episode  360 score -184.23 trailing 100 games avg -114.815
# episode  361 score -100.28 trailing 100 games avg -114.178
# episode  362 score -347.46 trailing 100 games avg -116.659
# episode  363 score -202.00 trailing 100 games avg -117.640
# episode  364 score -157.75 trailing 100 games avg -118.520
# episode  365 score -245.86 trailing 100 games avg -120.606
# episode  366 score -219.25 trailing 100 games avg -122.369
# episode  367 score -266.78 trailing 100 games avg -123.659
# episode  368 score -344.88 trailing 100 games avg -125.262
# episode  369 score -217.48 trailing 100 games avg -125.542
# episode  370 score 246.69 trailing 100 games avg -121.276
# episode  371 score -320.00 trailing 100 games avg -123.292
# episode  372 score -105.30 trailing 100 games avg -122.225
# episode  373 score -125.88 trailing 100 games avg -121.533
# episode  374 score -244.98 trailing 100 games avg -121.380
# episode  375 score -454.41 trailing 100 games avg -123.457
# episode  376 score 13.47 trailing 100 games avg -122.346
# episode  377 score -84.64 trailing 100 games avg -122.574
# episode  378 score -88.71 trailing 100 games avg -122.643
# episode  379 score -93.66 trailing 100 games avg -123.361
# episode  380 score -136.39 trailing 100 games avg -124.936
# episode  381 score -49.03 trailing 100 games avg -125.417
# episode  382 score -286.25 trailing 100 games avg -125.873
# episode  383 score -205.41 trailing 100 games avg -126.976
# episode  384 score -241.66 trailing 100 games avg -129.049
# episode  385 score -60.62 trailing 100 games avg -128.788
# episode  386 score -162.52 trailing 100 games avg -130.293
# episode  387 score -367.95 trailing 100 games avg -133.475
# episode  388 score -246.26 trailing 100 games avg -135.092
# episode  389 score -76.48 trailing 100 games avg -135.205
# episode  390 score -174.97 trailing 100 games avg -135.761
# episode  391 score -29.12 trailing 100 games avg -135.608
# episode  392 score -367.57 trailing 100 games avg -138.249
# episode  393 score -16.15 trailing 100 games avg -137.658
# episode  394 score -105.98 trailing 100 games avg -137.810
# episode  395 score -236.47 trailing 100 games avg -137.151
# episode  396 score -40.01 trailing 100 games avg -135.789
# episode  397 score -221.00 trailing 100 games avg -136.392
# episode  398 score -284.75 trailing 100 games avg -137.655
# episode  399 score -217.39 trailing 100 games avg -138.651
# episode  400 score -150.28 trailing 100 games avg -139.291
# episode  401 score -145.95 trailing 100 games avg -140.256
# episode  402 score -330.61 trailing 100 games avg -142.934
# episode  403 score -78.37 trailing 100 games avg -143.403
# episode  404 score -157.01 trailing 100 games avg -144.818
# episode  405 score -223.81 trailing 100 games avg -145.637
# episode  406 score -332.55 trailing 100 games avg -148.215
# episode  407 score -462.88 trailing 100 games avg -151.929
# episode  408 score -252.20 trailing 100 games avg -153.773
# episode  409 score -110.38 trailing 100 games avg -154.445
# episode  410 score -83.18 trailing 100 games avg -154.368
# episode  411 score -62.13 trailing 100 games avg -153.740
# episode  412 score -25.82 trailing 100 games avg -153.227
# episode  413 score -25.80 trailing 100 games avg -152.667
# episode  414 score -23.52 trailing 100 games avg -152.934
# episode  415 score -363.39 trailing 100 games avg -156.284
# episode  416 score -350.57 trailing 100 games avg -157.602
# episode  417 score -343.20 trailing 100 games avg -159.579
# episode  418 score -57.55 trailing 100 games avg -154.380
# episode  419 score -112.68 trailing 100 games avg -152.849
# episode  420 score -50.32 trailing 100 games avg -150.428
# episode  421 score -71.45 trailing 100 games avg -148.482
# episode  422 score -16.09 trailing 100 games avg -148.133
# episode  423 score -38.90 trailing 100 games avg -147.773
# episode  424 score -60.41 trailing 100 games avg -148.704
# episode  425 score -59.74 trailing 100 games avg -148.887
# episode  426 score -36.94 trailing 100 games avg -148.245
# episode  427 score -73.41 trailing 100 games avg -148.138
# episode  428 score -46.96 trailing 100 games avg -148.272
# episode  429 score -72.48 trailing 100 games avg -148.400
# episode  430 score -97.86 trailing 100 games avg -147.116
# episode  431 score -80.44 trailing 100 games avg -148.102
# episode  432 score -24.36 trailing 100 games avg -146.744
# episode  433 score -66.23 trailing 100 games avg -146.997
# episode  434 score -7.55 trailing 100 games avg -147.138
# episode  435 score -36.33 trailing 100 games avg -146.658
# episode  436 score -16.54 trailing 100 games avg -144.382
# episode  437 score -46.64 trailing 100 games avg -146.930
# episode  438 score -56.49 trailing 100 games avg -146.868
# episode  439 score -31.28 trailing 100 games avg -146.825
# episode  440 score -222.57 trailing 100 games avg -148.122
# episode  441 score -154.79 trailing 100 games avg -149.640
# episode  442 score -82.00 trailing 100 games avg -150.498
# episode  443 score -70.46 trailing 100 games avg -148.872
# episode  444 score -17.59 trailing 100 games avg -148.294
# episode  445 score -51.73 trailing 100 games avg -145.971
# episode  446 score 58.09 trailing 100 games avg -142.759
# episode  447 score -68.98 trailing 100 games avg -141.809
# episode  448 score -229.85 trailing 100 games avg -141.186
# episode  449 score -162.95 trailing 100 games avg -140.479
# episode  450 score -66.27 trailing 100 games avg -140.238
# episode  451 score -52.16 trailing 100 games avg -139.485
# episode  452 score -114.48 trailing 100 games avg -139.618
# episode  453 score -29.63 trailing 100 games avg -139.715
# episode  454 score -86.72 trailing 100 games avg -139.871
# episode  455 score -234.19 trailing 100 games avg -140.765
# episode  456 score -200.30 trailing 100 games avg -140.760
# episode  457 score -22.53 trailing 100 games avg -138.310
# episode  458 score -69.48 trailing 100 games avg -138.021
# episode  459 score -46.43 trailing 100 games avg -136.766
# episode  460 score -166.98 trailing 100 games avg -136.594
# episode  461 score -169.42 trailing 100 games avg -137.285
# episode  462 score -251.11 trailing 100 games avg -136.322
# episode  463 score -73.43 trailing 100 games avg -135.036
# episode  464 score -103.12 trailing 100 games avg -134.490
# episode  465 score -64.35 trailing 100 games avg -132.675
# episode  466 score -49.94 trailing 100 games avg -130.982
# episode  467 score -78.59 trailing 100 games avg -129.100
# episode  468 score -74.70 trailing 100 games avg -126.398
# episode  469 score -109.01 trailing 100 games avg -125.313
# episode  470 score -54.21 trailing 100 games avg -128.322
# episode  471 score -362.72 trailing 100 games avg -128.749
# episode  472 score -205.66 trailing 100 games avg -129.753
# episode  473 score -71.91 trailing 100 games avg -129.213
# episode  474 score -61.94 trailing 100 games avg -127.383
# episode  475 score 12.50 trailing 100 games avg -122.714
# episode  476 score -68.11 trailing 100 games avg -123.530
# episode  477 score -40.23 trailing 100 games avg -123.085
# episode  478 score -217.23 trailing 100 games avg -124.371
# episode  479 score -149.01 trailing 100 games avg -124.924
# episode  480 score -15.64 trailing 100 games avg -123.717
# episode  481 score -61.61 trailing 100 games avg -123.842
# episode  482 score -175.56 trailing 100 games avg -122.736
# episode  483 score -158.82 trailing 100 games avg -122.270
# episode  484 score -35.63 trailing 100 games avg -120.210
# episode  485 score -30.89 trailing 100 games avg -119.912
# episode  486 score -35.02 trailing 100 games avg -118.637
# episode  487 score -157.55 trailing 100 games avg -116.533
# episode  488 score -103.43 trailing 100 games avg -115.105
# episode  489 score -21.67 trailing 100 games avg -114.557
# episode  490 score 228.42 trailing 100 games avg -110.523
# episode  491 score -17.86 trailing 100 games avg -110.410
# episode  492 score 18.65 trailing 100 games avg -106.548
# episode  493 score -25.28 trailing 100 games avg -106.639
# episode  494 score -42.03 trailing 100 games avg -106.000
# episode  495 score -23.84 trailing 100 games avg -103.874
# episode  496 score -91.59 trailing 100 games avg -104.389
# episode  497 score -25.20 trailing 100 games avg -102.431
# episode  498 score -189.80 trailing 100 games avg -101.482
# episode  499 score -215.65 trailing 100 games avg -101.464
# episode  500 score -23.07 trailing 100 games avg -100.192
# episode  501 score -25.11 trailing 100 games avg -98.984
# episode  502 score -26.98 trailing 100 games avg -95.948
# episode  503 score -41.64 trailing 100 games avg -95.580
# episode  504 score -114.21 trailing 100 games avg -95.152
# episode  505 score -67.08 trailing 100 games avg -93.585
# episode  506 score -43.99 trailing 100 games avg -90.699
# episode  507 score -35.43 trailing 100 games avg -86.425
# episode  508 score -50.43 trailing 100 games avg -84.407
# episode  509 score -133.43 trailing 100 games avg -84.638
# episode  510 score -64.90 trailing 100 games avg -84.455
# episode  511 score -52.50 trailing 100 games avg -84.359
# episode  512 score -79.35 trailing 100 games avg -84.894
# episode  513 score -34.78 trailing 100 games avg -84.984
# episode  514 score -104.07 trailing 100 games avg -85.789
# episode  515 score -48.23 trailing 100 games avg -82.638
# episode  516 score -44.36 trailing 100 games avg -79.575
# episode  517 score -399.26 trailing 100 games avg -80.136
# episode  518 score -123.66 trailing 100 games avg -80.797
# episode  519 score -34.98 trailing 100 games avg -80.020
# episode  520 score -51.32 trailing 100 games avg -80.030
# episode  521 score -80.52 trailing 100 games avg -80.121
# episode  522 score -52.34 trailing 100 games avg -80.483
# episode  523 score -70.19 trailing 100 games avg -80.796
# episode  524 score -54.60 trailing 100 games avg -80.738
# episode  525 score -82.92 trailing 100 games avg -80.970
# episode  526 score -20.65 trailing 100 games avg -80.807
# episode  527 score -20.80 trailing 100 games avg -80.281
# episode  528 score -105.25 trailing 100 games avg -80.864
# episode  529 score -141.03 trailing 100 games avg -81.550
# episode  530 score -15.51 trailing 100 games avg -80.726
# episode  531 score -55.92 trailing 100 games avg -80.481
# episode  532 score -104.45 trailing 100 games avg -81.282
# episode  533 score -58.71 trailing 100 games avg -81.206
# episode  534 score -28.52 trailing 100 games avg -81.416
# episode  535 score -194.71 trailing 100 games avg -83.000
# episode  536 score -87.02 trailing 100 games avg -83.705
# episode  537 score 5.43 trailing 100 games avg -83.184
# episode  538 score -85.34 trailing 100 games avg -83.473
# episode  539 score -182.19 trailing 100 games avg -84.982
# episode  540 score -68.03 trailing 100 games avg -83.436
# episode  541 score -66.30 trailing 100 games avg -82.551
# episode  542 score -91.79 trailing 100 games avg -82.649
# episode  543 score -19.71 trailing 100 games avg -82.142
# episode  544 score 43.04 trailing 100 games avg -81.536
# episode  545 score -188.19 trailing 100 games avg -82.900
# episode  546 score -58.17 trailing 100 games avg -84.063
# episode  547 score -89.09 trailing 100 games avg -84.264
# episode  548 score -86.11 trailing 100 games avg -82.827
# episode  549 score -27.76 trailing 100 games avg -81.475
# episode  550 score -36.97 trailing 100 games avg -81.182
# episode  551 score -31.13 trailing 100 games avg -80.971
# episode  552 score -34.56 trailing 100 games avg -80.172
# episode  553 score -61.66 trailing 100 games avg -80.493
# episode  554 score -69.76 trailing 100 games avg -80.323
# episode  555 score -75.72 trailing 100 games avg -78.738
# episode  556 score -42.60 trailing 100 games avg -77.161
# episode  557 score 21.95 trailing 100 games avg -76.716
# episode  558 score 58.56 trailing 100 games avg -75.436
# episode  559 score -49.20 trailing 100 games avg -75.464
# episode  560 score -178.78 trailing 100 games avg -75.582
# episode  561 score -54.40 trailing 100 games avg -74.432
# episode  562 score -65.71 trailing 100 games avg -72.578
# episode  563 score -394.88 trailing 100 games avg -75.792
# episode  564 score -194.23 trailing 100 games avg -76.703
# episode  565 score -208.71 trailing 100 games avg -78.147
# episode  566 score -19.99 trailing 100 games avg -77.847
# episode  567 score -8.40 trailing 100 games avg -77.145
# episode  568 score -165.86 trailing 100 games avg -78.057
# episode  569 score -153.49 trailing 100 games avg -78.502
# episode  570 score -34.32 trailing 100 games avg -78.303
# episode  571 score -52.87 trailing 100 games avg -75.205
# episode  572 score -20.32 trailing 100 games avg -73.351
# episode  573 score -43.21 trailing 100 games avg -73.064
# episode  574 score -169.38 trailing 100 games avg -74.138
# episode  575 score -141.75 trailing 100 games avg -75.681
# episode  576 score -128.67 trailing 100 games avg -76.287
# episode  577 score -23.90 trailing 100 games avg -76.123
# episode  578 score -14.20 trailing 100 games avg -74.093
# episode  579 score -237.09 trailing 100 games avg -74.974
# episode  580 score -68.36 trailing 100 games avg -75.501
# episode  581 score -122.88 trailing 100 games avg -76.114
# episode  582 score -212.34 trailing 100 games avg -76.481
# episode  583 score -76.41 trailing 100 games avg -75.657
# episode  584 score -83.98 trailing 100 games avg -76.141
# episode  585 score -84.17 trailing 100 games avg -76.674
# episode  586 score -135.05 trailing 100 games avg -77.674
# episode  587 score -63.76 trailing 100 games avg -76.736
# episode  588 score -69.00 trailing 100 games avg -76.392
# episode  589 score -29.76 trailing 100 games avg -76.473
# episode  590 score -5.18 trailing 100 games avg -78.809
# episode  591 score -80.37 trailing 100 games avg -79.434
# episode  592 score -100.46 trailing 100 games avg -80.625
# episode  593 score -54.03 trailing 100 games avg -80.912
# episode  594 score -43.09 trailing 100 games avg -80.923
# episode  595 score -257.23 trailing 100 games avg -83.257
# episode  596 score 35.91 trailing 100 games avg -81.982
# episode  597 score -19.07 trailing 100 games avg -81.921
# episode  598 score -193.56 trailing 100 games avg -81.958
# episode  599 score -17.28 trailing 100 games avg -79.974
# episode  600 score -40.58 trailing 100 games avg -80.150
# episode  601 score -52.37 trailing 100 games avg -80.422
# episode  602 score -262.48 trailing 100 games avg -82.777
# episode  603 score -123.31 trailing 100 games avg -83.594
# episode  604 score -71.40 trailing 100 games avg -83.166
# episode  605 score -22.12 trailing 100 games avg -82.716
# episode  606 score -136.17 trailing 100 games avg -83.638
# episode  607 score -10.91 trailing 100 games avg -83.393
# episode  608 score -230.02 trailing 100 games avg -85.189
# episode  609 score -71.58 trailing 100 games avg -84.570
# episode  610 score -137.20 trailing 100 games avg -85.293
# episode  611 score -67.45 trailing 100 games avg -85.443
# episode  612 score -25.96 trailing 100 games avg -84.909
# episode  613 score -78.35 trailing 100 games avg -85.344
# episode  614 score -258.07 trailing 100 games avg -86.884
# episode  615 score -158.89 trailing 100 games avg -87.991
# episode  616 score -163.61 trailing 100 games avg -89.183
# episode  617 score -164.04 trailing 100 games avg -86.831
# episode  618 score -101.34 trailing 100 games avg -86.608
# episode  619 score -189.09 trailing 100 games avg -88.149
# episode  620 score -47.16 trailing 100 games avg -88.108
# episode  621 score -127.25 trailing 100 games avg -88.575
# episode  622 score -36.76 trailing 100 games avg -88.419
# episode  623 score -30.11 trailing 100 games avg -88.018
# episode  624 score -52.45 trailing 100 games avg -87.997
# episode  625 score -196.62 trailing 100 games avg -89.134
# episode  626 score -64.87 trailing 100 games avg -89.576
# episode  627 score -27.48 trailing 100 games avg -89.643
# episode  628 score -15.84 trailing 100 games avg -88.749
# episode  629 score -44.58 trailing 100 games avg -87.784
# episode  630 score -73.07 trailing 100 games avg -88.360
# episode  631 score 10.27 trailing 100 games avg -87.698
# episode  632 score -65.08 trailing 100 games avg -87.304
# episode  633 score -102.12 trailing 100 games avg -87.738
# episode  634 score -33.75 trailing 100 games avg -87.791
# episode  635 score -120.91 trailing 100 games avg -87.053
# episode  636 score -126.28 trailing 100 games avg -87.445
# episode  637 score -91.13 trailing 100 games avg -88.411
# episode  638 score -11.37 trailing 100 games avg -87.671
# episode  639 score -27.92 trailing 100 games avg -86.129
# episode  640 score -45.91 trailing 100 games avg -85.907
# episode  641 score -43.48 trailing 100 games avg -85.679
# episode  642 score -52.06 trailing 100 games avg -85.282
# episode  643 score -68.97 trailing 100 games avg -85.774
# episode  644 score 120.62 trailing 100 games avg -84.999
# episode  645 score -53.98 trailing 100 games avg -83.656
# episode  646 score -18.25 trailing 100 games avg -83.257
# episode  647 score -44.43 trailing 100 games avg -82.811
# episode  648 score -153.14 trailing 100 games avg -83.481
# episode  649 score -125.15 trailing 100 games avg -84.455
# episode  650 score -50.14 trailing 100 games avg -84.587
# episode  651 score -168.40 trailing 100 games avg -85.959
# episode  652 score -20.16 trailing 100 games avg -85.815
# episode  653 score -164.10 trailing 100 games avg -86.840
# episode  654 score 131.33 trailing 100 games avg -84.829
# episode  655 score -175.65 trailing 100 games avg -85.828
# episode  656 score -62.02 trailing 100 games avg -86.022
# episode  657 score -30.07 trailing 100 games avg -86.542
# episode  658 score -56.49 trailing 100 games avg -87.693
# episode  659 score -276.93 trailing 100 games avg -89.970
# episode  660 score -156.01 trailing 100 games avg -89.743
# episode  661 score -38.92 trailing 100 games avg -89.588
# episode  662 score -257.03 trailing 100 games avg -91.501
# episode  663 score -111.28 trailing 100 games avg -88.665
# episode  664 score -57.58 trailing 100 games avg -87.298
# episode  665 score -111.93 trailing 100 games avg -86.331
# episode  666 score -61.71 trailing 100 games avg -86.748
# episode  667 score -107.85 trailing 100 games avg -87.742
# episode  668 score -10.53 trailing 100 games avg -86.189
# episode  669 score -156.20 trailing 100 games avg -86.216
# episode  670 score -22.22 trailing 100 games avg -86.095
# episode  671 score -230.17 trailing 100 games avg -87.868
# episode  672 score -64.51 trailing 100 games avg -88.310
# episode  673 score -91.87 trailing 100 games avg -88.797
# episode  674 score -24.25 trailing 100 games avg -87.345
# episode  675 score -44.28 trailing 100 games avg -86.371
# episode  676 score -99.51 trailing 100 games avg -86.079
# episode  677 score 0.28 trailing 100 games avg -85.837
# episode  678 score -52.44 trailing 100 games avg -86.220
# episode  679 score -50.51 trailing 100 games avg -84.354
# episode  680 score -71.91 trailing 100 games avg -84.390
# episode  681 score 253.82 trailing 100 games avg -80.623
# episode  682 score -43.53 trailing 100 games avg -78.935
# episode  683 score -47.75 trailing 100 games avg -78.648
# episode  684 score -83.81 trailing 100 games avg -78.646
# episode  685 score -231.10 trailing 100 games avg -80.115
# episode  686 score -20.78 trailing 100 games avg -78.973
# episode  687 score 3.35 trailing 100 games avg -78.302
# episode  688 score -113.69 trailing 100 games avg -78.748
# episode  689 score -140.54 trailing 100 games avg -79.856
# episode  690 score -188.71 trailing 100 games avg -81.692
# episode  691 score -182.27 trailing 100 games avg -82.711
# episode  692 score -53.05 trailing 100 games avg -82.237
# episode  693 score -4.95 trailing 100 games avg -81.746
# episode  694 score -28.33 trailing 100 games avg -81.598
# episode  695 score -52.39 trailing 100 games avg -79.550
# episode  696 score -59.04 trailing 100 games avg -80.499
# episode  697 score -30.26 trailing 100 games avg -80.611
# episode  698 score 11.60 trailing 100 games avg -78.560
# episode  699 score -78.35 trailing 100 games avg -79.170
# episode  700 score -169.62 trailing 100 games avg -80.461
# episode  701 score -62.70 trailing 100 games avg -80.564
# episode  702 score -223.44 trailing 100 games avg -80.173
# episode  703 score -13.57 trailing 100 games avg -79.076
# episode  704 score -24.23 trailing 100 games avg -78.604
# episode  705 score -153.97 trailing 100 games avg -79.923
# episode  706 score -4.69 trailing 100 games avg -78.608
# episode  707 score 215.12 trailing 100 games avg -76.348
# episode  708 score -50.40 trailing 100 games avg -74.552
# episode  709 score -77.60 trailing 100 games avg -74.612
# episode  710 score -9.25 trailing 100 games avg -73.332
# episode  711 score -41.87 trailing 100 games avg -73.077
# episode  712 score -30.23 trailing 100 games avg -73.119
# episode  713 score -34.80 trailing 100 games avg -72.684
# episode  714 score -75.68 trailing 100 games avg -70.860
# episode  715 score -270.75 trailing 100 games avg -71.979
# episode  716 score -0.25 trailing 100 games avg -70.345
# episode  717 score -124.69 trailing 100 games avg -69.952
# episode  718 score -31.43 trailing 100 games avg -69.252
# episode  719 score -118.10 trailing 100 games avg -68.543
# episode  720 score -74.30 trailing 100 games avg -68.814
# episode  721 score -37.12 trailing 100 games avg -67.913
# episode  722 score -69.64 trailing 100 games avg -68.241
# episode  723 score -154.83 trailing 100 games avg -69.488
# episode  724 score -39.02 trailing 100 games avg -69.354
# episode  725 score -47.96 trailing 100 games avg -67.868
# episode  726 score -210.09 trailing 100 games avg -69.320
# episode  727 score -86.05 trailing 100 games avg -69.905
# episode  728 score 228.08 trailing 100 games avg -67.466
# episode  729 score -143.52 trailing 100 games avg -68.456
# episode  730 score -138.21 trailing 100 games avg -69.107
# episode  731 score -72.16 trailing 100 games avg -69.931
# episode  732 score -81.02 trailing 100 games avg -70.091
# episode  733 score 184.86 trailing 100 games avg -67.221
# episode  734 score 10.11 trailing 100 games avg -66.782
# episode  735 score -28.68 trailing 100 games avg -65.860
# episode  736 score -128.99 trailing 100 games avg -65.887
# episode  737 score -11.92 trailing 100 games avg -65.095
# episode  738 score -20.66 trailing 100 games avg -65.188
# episode  739 score -37.86 trailing 100 games avg -65.287
# episode  740 score -59.11 trailing 100 games avg -65.419
# episode  741 score -151.48 trailing 100 games avg -66.499
# episode  742 score -174.60 trailing 100 games avg -67.725
# episode  743 score -177.98 trailing 100 games avg -68.815
# episode  744 score -303.93 trailing 100 games avg -73.060
# episode  745 score 12.03 trailing 100 games avg -72.400
# episode  746 score -134.73 trailing 100 games avg -73.565
# episode  747 score -98.76 trailing 100 games avg -74.108
# episode  748 score -103.38 trailing 100 games avg -73.611
# episode  749 score -55.06 trailing 100 games avg -72.910
# episode  750 score -54.97 trailing 100 games avg -72.958
# episode  751 score -83.56 trailing 100 games avg -72.110
# episode  752 score 25.29 trailing 100 games avg -71.655
# episode  753 score -34.32 trailing 100 games avg -70.357
# episode  754 score 159.05 trailing 100 games avg -70.080
# episode  755 score -66.50 trailing 100 games avg -68.989
# episode  756 score -181.87 trailing 100 games avg -70.187
# episode  757 score -67.28 trailing 100 games avg -70.559
# episode  758 score -142.39 trailing 100 games avg -71.418
# episode  759 score -104.36 trailing 100 games avg -69.693
# episode  760 score -14.54 trailing 100 games avg -68.278
# episode  761 score -34.33 trailing 100 games avg -68.232
# episode  762 score -162.80 trailing 100 games avg -67.290
# episode  763 score 60.31 trailing 100 games avg -65.574
# episode  764 score -65.72 trailing 100 games avg -65.655
# episode  765 score -182.11 trailing 100 games avg -66.357
# episode  766 score -140.51 trailing 100 games avg -67.145
# episode  767 score -240.48 trailing 100 games avg -68.471
# episode  768 score -31.12 trailing 100 games avg -68.677
# episode  769 score -17.84 trailing 100 games avg -67.294
# episode  770 score -40.11 trailing 100 games avg -67.473
# episode  771 score -23.29 trailing 100 games avg -65.404
# episode  772 score -105.21 trailing 100 games avg -65.811
# episode  773 score 12.10 trailing 100 games avg -64.771
# episode  774 score -69.66 trailing 100 games avg -65.225
# episode  775 score -56.26 trailing 100 games avg -65.345
# episode  776 score -42.04 trailing 100 games avg -64.770
# episode  777 score -39.68 trailing 100 games avg -65.170
# episode  778 score -35.93 trailing 100 games avg -65.005
# episode  779 score -36.55 trailing 100 games avg -64.865
# episode  780 score -66.32 trailing 100 games avg -64.809
# episode  781 score -73.65 trailing 100 games avg -68.084
# episode  782 score -64.19 trailing 100 games avg -68.290
# episode  783 score -7.21 trailing 100 games avg -67.885
# episode  784 score -139.07 trailing 100 games avg -68.438
# episode  785 score -34.91 trailing 100 games avg -66.476
# episode  786 score -211.52 trailing 100 games avg -68.383
# episode  787 score -34.23 trailing 100 games avg -68.759
# episode  788 score -32.73 trailing 100 games avg -67.949
# episode  789 score -348.06 trailing 100 games avg -70.024
# episode  790 score -27.07 trailing 100 games avg -68.408
# episode  791 score -22.82 trailing 100 games avg -66.814
# episode  792 score -37.45 trailing 100 games avg -66.658
# episode  793 score -15.20 trailing 100 games avg -66.760
# episode  794 score -114.98 trailing 100 games avg -67.626
# episode  795 score -43.58 trailing 100 games avg -67.538
# episode  796 score -113.83 trailing 100 games avg -68.086
# episode  797 score -40.38 trailing 100 games avg -68.187
# episode  798 score 5.32 trailing 100 games avg -68.250
# episode  799 score -445.51 trailing 100 games avg -71.922
# episode  800 score -5.28 trailing 100 games avg -70.278
# episode  801 score -80.47 trailing 100 games avg -70.456
# episode  802 score -59.65 trailing 100 games avg -68.818
# episode  803 score -59.93 trailing 100 games avg -69.282
# episode  804 score -168.29 trailing 100 games avg -70.722
# episode  805 score -105.72 trailing 100 games avg -70.240
# episode  806 score -14.51 trailing 100 games avg -70.338
# episode  807 score -97.46 trailing 100 games avg -73.464
# episode  808 score -199.99 trailing 100 games avg -74.960
# episode  809 score -93.30 trailing 100 games avg -75.117
# episode  810 score 130.80 trailing 100 games avg -73.716
# episode  811 score -205.68 trailing 100 games avg -75.354
# episode  812 score -88.69 trailing 100 games avg -75.939
# episode  813 score -147.22 trailing 100 games avg -77.063
# episode  814 score -60.26 trailing 100 games avg -76.909
# episode  815 score -21.77 trailing 100 games avg -74.419
# episode  816 score -26.83 trailing 100 games avg -74.685
# episode  817 score -100.63 trailing 100 games avg -74.444
# episode  818 score -62.12 trailing 100 games avg -74.751
# episode  819 score -13.52 trailing 100 games avg -73.706
# episode  820 score -94.73 trailing 100 games avg -73.910
# episode  821 score -73.32 trailing 100 games avg -74.272
# episode  822 score 27.48 trailing 100 games avg -73.301
# episode  823 score -30.55 trailing 100 games avg -72.058
# episode  824 score -61.88 trailing 100 games avg -72.286
# episode  825 score 77.87 trailing 100 games avg -71.028
# episode  826 score -68.91 trailing 100 games avg -69.616
# episode  827 score 26.84 trailing 100 games avg -68.487
# episode  828 score -377.42 trailing 100 games avg -74.543
# episode  829 score -429.62 trailing 100 games avg -77.403
# episode  830 score -98.42 trailing 100 games avg -77.006
# episode  831 score -160.98 trailing 100 games avg -77.894
# episode  832 score -74.08 trailing 100 games avg -77.824
# episode  833 score 5.75 trailing 100 games avg -79.615
# episode  834 score 10.17 trailing 100 games avg -79.615
# episode  835 score -177.42 trailing 100 games avg -81.102
# episode  836 score -41.69 trailing 100 games avg -80.229
# episode  837 score -25.72 trailing 100 games avg -80.367
# episode  838 score 22.25 trailing 100 games avg -79.938
# episode  839 score -11.42 trailing 100 games avg -79.674
# episode  840 score -51.41 trailing 100 games avg -79.597
# episode  841 score 154.20 trailing 100 games avg -76.540
# episode  842 score -40.12 trailing 100 games avg -75.195
# episode  843 score 121.82 trailing 100 games avg -72.197
# episode  844 score -83.53 trailing 100 games avg -69.993
# episode  845 score -35.38 trailing 100 games avg -70.467
# episode  846 score -86.19 trailing 100 games avg -69.982
# episode  847 score -64.51 trailing 100 games avg -69.639
# episode  848 score -49.02 trailing 100 games avg -69.096
# episode  849 score -28.80 trailing 100 games avg -68.833
# episode  850 score 15.88 trailing 100 games avg -68.125
# episode  851 score 245.36 trailing 100 games avg -64.836
# episode  852 score 177.29 trailing 100 games avg -63.316
# episode  853 score -144.45 trailing 100 games avg -64.417
# episode  854 score -158.66 trailing 100 games avg -67.594
# episode  855 score -96.12 trailing 100 games avg -67.890
# episode  856 score -9.51 trailing 100 games avg -66.167
# episode  857 score -70.27 trailing 100 games avg -66.197
# episode  858 score 9.88 trailing 100 games avg -64.674
# episode  859 score -185.87 trailing 100 games avg -65.489
# episode  860 score -96.70 trailing 100 games avg -66.311
# episode  861 score -83.87 trailing 100 games avg -66.806
# episode  862 score -61.03 trailing 100 games avg -65.788
# episode  863 score -303.53 trailing 100 games avg -69.427
# episode  864 score -24.46 trailing 100 games avg -69.014
# episode  865 score 201.36 trailing 100 games avg -65.180
# episode  866 score 146.38 trailing 100 games avg -62.311
# episode  867 score -19.16 trailing 100 games avg -60.097
# episode  868 score -29.09 trailing 100 games avg -60.077
# episode  869 score -15.34 trailing 100 games avg -60.052
# episode  870 score 231.43 trailing 100 games avg -57.337
# episode  871 score -53.40 trailing 100 games avg -57.638
# episode  872 score -97.00 trailing 100 games avg -57.556
# episode  873 score 192.72 trailing 100 games avg -55.749
# episode  874 score -13.16 trailing 100 games avg -55.184
# episode  875 score 28.35 trailing 100 games avg -54.338
# episode  876 score -11.04 trailing 100 games avg -54.028
# episode  877 score -15.34 trailing 100 games avg -53.785
# episode  878 score -73.88 trailing 100 games avg -54.164
# episode  879 score -37.40 trailing 100 games avg -54.173
# episode  880 score 169.21 trailing 100 games avg -51.818
# episode  881 score -24.57 trailing 100 games avg -51.327
# episode  882 score -18.51 trailing 100 games avg -50.870
# episode  883 score -40.97 trailing 100 games avg -51.208
# episode  884 score 31.55 trailing 100 games avg -49.501
# episode  885 score 215.59 trailing 100 games avg -46.996
# episode  886 score -115.70 trailing 100 games avg -46.038
# episode  887 score -257.52 trailing 100 games avg -48.271
# episode  888 score -152.68 trailing 100 games avg -49.471
# episode  889 score 118.09 trailing 100 games avg -44.809
# episode  890 score -43.72 trailing 100 games avg -44.976
# episode  891 score 152.00 trailing 100 games avg -43.227
# episode  892 score 128.90 trailing 100 games avg -41.564
# episode  893 score 180.32 trailing 100 games avg -39.609
# episode  894 score -50.68 trailing 100 games avg -38.966
# episode  895 score -381.46 trailing 100 games avg -42.344
# episode  896 score -90.96 trailing 100 games avg -42.116
# episode  897 score -107.52 trailing 100 games avg -42.787
# episode  898 score -162.94 trailing 100 games avg -44.470
# episode  899 score -19.92 trailing 100 games avg -40.214
# episode  900 score -5.02 trailing 100 games avg -40.211
# episode  901 score 5.60 trailing 100 games avg -39.351
# episode  902 score -317.91 trailing 100 games avg -41.933
# episode  903 score 164.27 trailing 100 games avg -39.691
# episode  904 score -11.47 trailing 100 games avg -38.123
# episode  905 score -138.04 trailing 100 games avg -38.446
# episode  906 score 237.86 trailing 100 games avg -35.923
# episode  907 score 157.85 trailing 100 games avg -33.370
# episode  908 score -40.32 trailing 100 games avg -31.773
# episode  909 score 24.21 trailing 100 games avg -30.598
# episode  910 score 190.25 trailing 100 games avg -30.003
# episode  911 score 136.93 trailing 100 games avg -26.577
# episode  912 score -278.85 trailing 100 games avg -28.479
# episode  913 score -33.38 trailing 100 games avg -27.340
# episode  914 score -4.39 trailing 100 games avg -26.782
# episode  915 score 235.48 trailing 100 games avg -24.209
# episode  916 score 197.26 trailing 100 games avg -21.968
# episode  917 score -69.61 trailing 100 games avg -21.658
# episode  918 score -107.26 trailing 100 games avg -22.109
# episode  919 score -183.67 trailing 100 games avg -23.811
# episode  920 score 222.50 trailing 100 games avg -20.639
# episode  921 score -2.23 trailing 100 games avg -19.928
# episode  922 score -180.07 trailing 100 games avg -22.003
# episode  923 score -37.63 trailing 100 games avg -22.074
# episode  924 score -105.98 trailing 100 games avg -22.515
# episode  925 score 212.27 trailing 100 games avg -21.171
# episode  926 score 131.51 trailing 100 games avg -19.167
# episode  927 score 275.30 trailing 100 games avg -16.683
# episode  928 score 240.40 trailing 100 games avg -10.504
# episode  929 score -135.08 trailing 100 games avg -7.559
# episode  930 score 56.28 trailing 100 games avg -6.012
# episode  931 score -49.82 trailing 100 games avg -4.900
# episode  932 score -46.75 trailing 100 games avg -4.627
# episode  933 score 206.57 trailing 100 games avg -2.619
# episode  934 score 218.24 trailing 100 games avg -0.538
# episode  935 score 213.42 trailing 100 games avg 3.370
# episode  936 score -246.32 trailing 100 games avg 1.324
# episode  937 score 173.95 trailing 100 games avg 3.321
# episode  938 score 223.42 trailing 100 games avg 5.333
# episode  939 score 190.49 trailing 100 games avg 7.352
# episode  940 score 200.27 trailing 100 games avg 9.869
# episode  941 score 244.10 trailing 100 games avg 10.767
# episode  942 score -124.56 trailing 100 games avg 9.923
# episode  943 score -306.90 trailing 100 games avg 5.636
# episode  944 score -185.22 trailing 100 games avg 4.619
# episode  945 score -213.99 trailing 100 games avg 2.833
# episode  946 score -159.09 trailing 100 games avg 2.104
# episode  947 score -75.65 trailing 100 games avg 1.992
# episode  948 score -185.74 trailing 100 games avg 0.625
# episode  949 score -229.80 trailing 100 games avg -1.385
# episode  950 score -262.53 trailing 100 games avg -4.169
# episode  951 score 150.53 trailing 100 games avg -5.117
# episode  952 score 180.36 trailing 100 games avg -5.086
# episode  953 score -90.99 trailing 100 games avg -4.552
# episode  954 score -35.79 trailing 100 games avg -3.323
# episode  955 score -174.54 trailing 100 games avg -4.107
# episode  956 score 190.92 trailing 100 games avg -2.103
# episode  957 score -29.19 trailing 100 games avg -1.692
# episode  958 score 181.40 trailing 100 games avg 0.023
# episode  959 score -57.64 trailing 100 games avg 1.306
# episode  960 score 182.15 trailing 100 games avg 4.094
# episode  961 score 276.08 trailing 100 games avg 7.694
# episode  962 score -62.93 trailing 100 games avg 7.675
# episode  963 score 183.46 trailing 100 games avg 12.545
# episode  964 score -113.24 trailing 100 games avg 11.657
# episode  965 score -45.54 trailing 100 games avg 9.188
# episode  966 score -102.57 trailing 100 games avg 6.698
# episode  967 score 17.50 trailing 100 games avg 7.065
# episode  968 score -356.84 trailing 100 games avg 3.788
# episode  969 score -145.07 trailing 100 games avg 2.490
# episode  970 score -27.12 trailing 100 games avg -0.095
# episode  971 score -69.64 trailing 100 games avg -0.258
# episode  972 score 42.47 trailing 100 games avg 1.137
# episode  973 score -148.78 trailing 100 games avg -2.278
# episode  974 score 135.59 trailing 100 games avg -0.791
# episode  975 score -40.28 trailing 100 games avg -1.477
# episode  976 score 236.10 trailing 100 games avg 0.995
# episode  977 score 29.46 trailing 100 games avg 1.443
# episode  978 score 259.72 trailing 100 games avg 4.779
# episode  979 score -191.37 trailing 100 games avg 3.239
# episode  980 score -26.83 trailing 100 games avg 1.278
# episode  981 score 53.36 trailing 100 games avg 2.058
# episode  982 score 218.90 trailing 100 games avg 4.432
# episode  983 score 164.03 trailing 100 games avg 6.482
# episode  984 score -4.51 trailing 100 games avg 6.121
# episode  985 score 228.94 trailing 100 games avg 6.255
# episode  986 score 231.78 trailing 100 games avg 9.730
# episode  987 score 269.61 trailing 100 games avg 15.001
# episode  988 score 216.65 trailing 100 games avg 18.694
# episode  989 score -229.16 trailing 100 games avg 15.222
# episode  990 score 183.63 trailing 100 games avg 17.495
# episode  991 score -3.03 trailing 100 games avg 15.945
# episode  992 score 282.22 trailing 100 games avg 17.478
# episode  993 score 291.42 trailing 100 games avg 18.589
# episode  994 score 9.09 trailing 100 games avg 19.187
# episode  995 score 196.15 trailing 100 games avg 24.963
# episode  996 score -14.43 trailing 100 games avg 25.728
# episode  997 score -115.91 trailing 100 games avg 25.644
# episode  998 score -13.19 trailing 100 games avg 27.142
# episode  999 score 148.59 trailing 100 games avg 28.827
